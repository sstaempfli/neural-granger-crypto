# %% [markdown]
# # Neural Granger Crypto Analysis
#
# This notebook:
#
# - Loads processed hourly features from `data/processed/features_<SYMBOL>.parquet` for BTCUSDT, ETHUSDT, and SOLUSDT.
# - Intersects the common time range, builds a multi-asset panel, and constructs lagged design matrices for multiple horizons.
# - Runs backtests over predefined train/test windows with seeds and sparsity sweeps.
# - Trains or reloads checkpoints for models: Last, VARX-LASSO, compact LSTM, NeuralGVAR (gated), and StaticGVAR.
# - Computes test metrics (MSE, MAE, SignHit) per run and aggregates them into `metrics_summary.csv`/`.tex`.
# - Builds hypothesis tables from `edge_hypothesis_summary`, plus `h1_summary`, `h4a_summary`, and `event_conditioning_summary` when those are computed.
# - Exports paper_assets into `paper_assets`, including:
#   - `metrics_summary.csv` and `metrics_summary.tex`
#   - `edge_key_edges_table.tex` and `key_edges_sign_table.tex` (key edge tables)
#   - `mse_*.png` / `mae_*.png` bar plots by task and horizon
#   - `h1_cond_*.png` and `h4a_cond_*.png` conditioning plots (if summaries exist)
#   - `edge_signfrac_keyedges.png` (sign-fraction vs horizon for key edges)

# %% [markdown]
# # Crypto Neural-GVAR Robust Analysis Notebook

# %%
# 0) Setup / Config
import os, math, random, warnings
from dataclasses import dataclass
from typing import Dict, List, Tuple

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore")

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

from sklearn.linear_model import MultiTaskLasso
from sklearn.preprocessing import StandardScaler

from pathlib import Path

FAST_MODE = False   # True for quick debug, False for paper runs
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
PRINT_EVERY = 1

DATA_DIR = Path("data")

# --- Checkpointing (set True to save trained models so you can reload without re-training)
SAVE_CHECKPOINTS = True
from pathlib import Path
# Checkpoints: saved per-model into separate subfolders for easier tracking.
CHECKPOINT_ROOT = Path('./checkpoints')  
MODEL_CKPT_DIRS = {
    'NeuralGVAR': CHECKPOINT_ROOT / 'NeuralGVAR',
    'StaticGVAR': CHECKPOINT_ROOT / 'StaticGVAR',
    'VARX_LASSO': CHECKPOINT_ROOT / 'VARX_LASSO',
    'LSTM': CHECKPOINT_ROOT / 'LSTM',
    'Last': CHECKPOINT_ROOT / 'Last',
}
# Ensure a stable variable CHECKPOINT_DIR is available for older code paths
CHECKPOINT_DIR = CHECKPOINT_ROOT
if SAVE_CHECKPOINTS:
    for _d in MODEL_CKPT_DIRS.values():
        _d.mkdir(parents=True, exist_ok=True)
    CHECKPOINT_DIR.mkdir(parents=True, exist_ok=True)
PROCESSED_DIR = DATA_DIR / "processed"

SYMBOLS = ["BTCUSDT", "ETHUSDT", "SOLUSDT"]
ASSET_IDX = {s:i for i,s in enumerate(SYMBOLS)}


RET_COL  = "ret_1h"
VOL_COL  = "realized_vol"
DIV_COL  = "rsi_div"
FUND_COL = "fundingRate"

LAGS_HOURS = [1, 3, 6, 12]
HORIZONS_H = [1, 4, 12, 24] if not FAST_MODE else [1, 12]

BACKTEST_WINDOWS = [
    ("2021-01-01", "2022-12-31 23:00", "2023-01-01", "2023-12-31 23:00"),
    ("2021-01-01", "2023-12-31 23:00", "2024-01-01", "2024-12-31 23:00"),
    ("2022-01-01", "2024-12-31 23:00", "2025-01-01", "2025-12-25 23:00"),
]
if FAST_MODE:
    BACKTEST_WINDOWS = [("2021-01-01", "2023-12-31 23:00", "2024-01-01", "2024-12-31 23:00")]

SEEDS = [1,2,3,4,5] if not FAST_MODE else [1,2]
LAMBDA_SPARSE_SWEEP = [1e-4, 5e-4, 1e-3] if not FAST_MODE else [5e-4]

EPOCHS = 25 if not FAST_MODE else 10
BATCH_SIZE = 256
LR = 3e-3

# Bootstrap / event settings
BOOT_BLOCK = 48
BOOT_N = 800 if not FAST_MODE else 200

EVENT_Q = 0.99
MATCH_BINS = 10
EVENT_PRE_H = 6
EVENT_POST_H = 6

print("DEVICE:", DEVICE, "| FAST_MODE:", FAST_MODE)
print("Horizons:", HORIZONS_H, "| windows:", len(BACKTEST_WINDOWS), "| seeds:", len(SEEDS), "| lambdas:", len(LAMBDA_SPARSE_SWEEP))
# Out:
# DEVICE: cpu | FAST_MODE: False
# Horizons: [1, 4, 12, 24] | windows: 3 | seeds: 5 | lambdas: 3

# %% [markdown]
# ## 1) Load features and trim to intersection window

# %%
def find_feature_file(symbol: str) -> Path:
    candidates = sorted(PROCESSED_DIR.glob(f"features_{symbol}.parquet"))
    if not candidates:
        raise FileNotFoundError(f"No parquet found for {symbol} in {PROCESSED_DIR}")
    candidates = sorted(candidates, key=lambda p: p.stat().st_mtime, reverse=True)
    return candidates[0]

def load_features(symbol: str) -> pd.DataFrame:
    p = find_feature_file(symbol)
    df = pd.read_parquet(p)
    if not isinstance(df.index, pd.DatetimeIndex):
        df.index = pd.to_datetime(df.index, utc=True)
    if df.index.tz is None:
        df.index = df.index.tz_localize("UTC")
    return df.sort_index()

def require_columns(df: pd.DataFrame, cols: List[str]) -> None:
    missing = [c for c in cols if c not in df.columns]
    if missing:
        raise KeyError(f"Missing columns {missing}. Example cols: {list(df.columns)[:40]}")

feature_dfs: Dict[str, pd.DataFrame] = {sym: load_features(sym) for sym in SYMBOLS}
for sym, df in feature_dfs.items():
    require_columns(df, [RET_COL, VOL_COL, DIV_COL, FUND_COL])

required_cols_all = [RET_COL, VOL_COL, DIV_COL, FUND_COL]
first_valid, last_valid = {}, {}
for sym, df in feature_dfs.items():
    mask = df[required_cols_all].notna().all(axis=1)
    first_valid[sym] = df.index[mask].min()
    last_valid[sym]  = df.index[mask].max()

intersection_start = max(first_valid.values())
intersection_end   = min(last_valid.values())

print("First valid per symbol:", first_valid)
print("Intersection:", intersection_start, "->", intersection_end)

for sym in feature_dfs:
    feature_dfs[sym] = feature_dfs[sym].loc[intersection_start:intersection_end]

panel = None
for sym, df in feature_dfs.items():
    tmp = df[[RET_COL, VOL_COL, DIV_COL, FUND_COL]].copy()
    tmp.columns = pd.MultiIndex.from_product([[sym], tmp.columns])
    panel = tmp if panel is None else panel.join(tmp, how="outer")

panel = panel.dropna()
panel.shape, panel.index.min(), panel.index.max()
# Out:
# First valid per symbol: {'BTCUSDT': Timestamp('2020-01-02 00:00:00+0000', tz='UTC'), 'ETHUSDT': Timestamp('2020-01-02 00:00:00+0000', tz='UTC'), 'SOLUSDT': Timestamp('2020-09-15 07:00:00+0000', tz='UTC')}
# Intersection: 2020-09-15 07:00:00+00:00 -> 2025-12-25 23:00:00+00:00
# ((46265, 12),
#  Timestamp('2020-09-15 07:00:00+0000', tz='UTC'),
#  Timestamp('2025-12-25 23:00:00+0000', tz='UTC'))

# %% [markdown]
# ## 2) Design matrix builder (lags + horizon)

# %%
@dataclass
class TaskSpec:
    name: str
    y_cols: List[Tuple[str,str]]
    x_cols: List[Tuple[str,str]]
    horizon_h: int

def make_design_matrix(df: pd.DataFrame, y_cols, x_cols, lags_h, horizon_h):
    y = df[y_cols].copy()
    x = df[x_cols].copy()

    lagged = []
    for k in lags_h:
        shifted = y.shift(k)
        shifted.columns = pd.MultiIndex.from_tuples([(a, f"{b}_lag{k}") for (a,b) in shifted.columns])
        lagged.append(shifted)
    Xy = pd.concat(lagged, axis=1)

    Xx = x.copy()
    Xx.columns = pd.MultiIndex.from_tuples([(a, f"{b}_t") for (a,b) in Xx.columns])

    Y = y.shift(-horizon_h)
    Y.columns = pd.MultiIndex.from_tuples([(a, f"{b}_t+{horizon_h}") for (a,b) in Y.columns])

    full = pd.concat([Xy, Xx, Y], axis=1).dropna()
    return full

def split_time(df: pd.DataFrame, train_start, train_end, test_start, test_end):
    train = df.loc[pd.Timestamp(train_start, tz="UTC"):pd.Timestamp(train_end, tz="UTC")]
    test  = df.loc[pd.Timestamp(test_start, tz="UTC"):pd.Timestamp(test_end, tz="UTC")]
    return train, test

RET_TASKS, VOL_TASKS = [], []
for h in HORIZONS_H:
    RET_TASKS.append(TaskSpec(
        name=f"RET_h{h}",
        y_cols=[(s, RET_COL) for s in SYMBOLS],
        x_cols=[(s, DIV_COL) for s in SYMBOLS] + [(s, FUND_COL) for s in SYMBOLS],
        horizon_h=h
    ))
    VOL_TASKS.append(TaskSpec(
        name=f"VOL_h{h}",
        y_cols=[(s, VOL_COL) for s in SYMBOLS],
        x_cols=[(s, DIV_COL) for s in SYMBOLS] + [(s, FUND_COL) for s in SYMBOLS],
        horizon_h=h
    ))

# %% [markdown]
# ## 3) Metrics + block bootstrap

# %%
def mse(y_true, y_pred): return float(np.mean((y_true - y_pred)**2))
def mae(y_true, y_pred): return float(np.mean(np.abs(y_true - y_pred)))
def sign_hit(y_true, y_pred): return float(np.mean(np.sign(y_true) == np.sign(y_pred)))

def block_bootstrap_ci(series: np.ndarray, stat_fn, block_size: int, n_boot: int, alpha: float = 0.05, seed: int = 0):
    rng = np.random.default_rng(seed)
    n = len(series)
    if n < block_size:
        return np.nan, np.nan
    n_blocks = int(np.ceil(n / block_size))
    stats=[]
    for _ in range(n_boot):
        idx=[]
        for _b in range(n_blocks):
            start = rng.integers(0, n - block_size + 1)
            idx.extend(range(start, start+block_size))
        idx = np.asarray(idx[:n])
        stats.append(stat_fn(series[idx]))
    return float(np.quantile(stats, alpha/2)), float(np.quantile(stats, 1-alpha/2))

# %% [markdown]
# ## 4) Baselines

# %%
class NumpyDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.from_numpy(X).float()
        self.y = torch.from_numpy(y).float()
    def __len__(self): return self.X.shape[0]
    def __getitem__(self, idx): return self.X[idx], self.y[idx]

class CompactLSTM(nn.Module):
    def __init__(self, input_dim, hidden=32, out_dim=3):
        super().__init__()
        self.lstm = nn.LSTM(input_dim, hidden, batch_first=True)
        self.fc = nn.Linear(hidden, out_dim)
    def forward(self, x):
        out,_ = self.lstm(x)
        return self.fc(out[:, -1, :])

def get_target_cols(y_cols, horizon_h):
    return [(sym, f"{feat}_t+{horizon_h}") for (sym, feat) in y_cols]

def run_last(full_test, y_cols, horizon_h):
    k = horizon_h if horizon_h in LAGS_HOURS else 1
    pred_cols = [(sym, f"{feat}_lag{k}") for (sym, feat) in y_cols]
    return full_test[get_target_cols(y_cols, horizon_h)].to_numpy(), full_test[pred_cols].to_numpy()

# helper to build LSTM sequences from the design-matrix style dataframe
def build_seq(full, y_cols, x_cols, lags_h, horizon_h):
    target_cols = get_target_cols(y_cols, horizon_h)
    Y = full[target_cols].to_numpy().astype(np.float32)
    steps = []
    for k in lags_h:
        step_cols = [(sym, f"{feat}_lag{k}") for (sym, feat) in y_cols]
        steps.append(full[step_cols].to_numpy().astype(np.float32))
    Xstate = full[[(sym, f"{feat}_t") for (sym, feat) in x_cols]].to_numpy().astype(np.float32)
    seq = np.stack(steps, axis=1)
    Xstate_rep = np.repeat(Xstate[:, None, :], seq.shape[1], axis=1)
    seq = np.concatenate([seq, Xstate_rep], axis=2)
    return seq, Y

def fit_varx_lasso(full_train, full_test, y_cols, horizon_h, alpha=1e-4, *,
                   return_model=False, checkpoint_path=None, meta=None):
    """VARX baseline (MultiTaskLasso) with optional checkpointing.

    Returns:
      - default: (Yte, Yhat)
      - if return_model=True: (Yte, Yhat, fitted_model, fitted_scaler)
    """
    from sklearn.linear_model import MultiTaskLasso
    from sklearn.preprocessing import StandardScaler
    import joblib, os

    target_cols = get_target_cols(y_cols, horizon_h)
    Xtr = full_train.drop(columns=target_cols).to_numpy()
    Ytr = full_train[target_cols].to_numpy()
    Xte = full_test.drop(columns=target_cols).to_numpy()
    Yte = full_test[target_cols].to_numpy()

    xs = StandardScaler()
    Xtr_s = xs.fit_transform(Xtr)
    Xte_s = xs.transform(Xte)

    model = MultiTaskLasso(alpha=alpha, fit_intercept=True, max_iter=10000)
    model.fit(Xtr_s, Ytr)
    Yhat = model.predict(Xte_s)

    if checkpoint_path is not None:
        try:
            os.makedirs(os.path.dirname(checkpoint_path), exist_ok=True)
            ckpt = {"model": model, "scaler": xs, "meta": meta or {}}
            joblib.dump(ckpt, checkpoint_path)
            print(f"[checkpoint] saved: {checkpoint_path}")
        except Exception as e:
            print(f"[checkpoint] WARNING: failed to save {checkpoint_path}: {e}")

    if return_model:
        return Yte, Yhat, model, xs
    return Yte, Yhat

def fit_compact_lstm(full_train, full_test, y_cols, x_cols, lags_h, horizon_h,
                     epochs=12, lr=3e-3, seed=0, *,
                     return_model=False, checkpoint_path=None, meta=None, hidden=32):
    """Compact LSTM baseline with optional checkpointing.

    Notes:
      - Expects the same design-matrix construction as the rest of the notebook.
      - Checkpoint stores model weights + minimal config to rebuild the module.
    """
    torch.manual_seed(seed); np.random.seed(seed); random.seed(seed)

    target_cols = get_target_cols(y_cols, horizon_h)
    Xtr_seq, Ytr = build_seq(full_train, y_cols, x_cols, lags_h, horizon_h)
    Xte_seq, Yte = build_seq(full_test,  y_cols, x_cols, lags_h, horizon_h)

    input_dim = Xtr_seq.shape[-1]
    out_dim = Ytr.shape[-1]

    model = CompactLSTM(input_dim=input_dim, hidden=hidden, out_dim=out_dim).to(DEVICE)
    dl = DataLoader(NumpyDataset(Xtr_seq, Ytr), batch_size=256, shuffle=True)
    opt = torch.optim.Adam(model.parameters(), lr=lr)
    loss_fn = nn.MSELoss()

    model.train()
    for ep in range(epochs):
        total=0.0
        for xb,yb in dl:
            xb,yb = xb.to(DEVICE), yb.to(DEVICE)
            opt.zero_grad()
            pred = model(xb)
            loss = loss_fn(pred, yb)
            loss.backward()
            opt.step()
            total += loss.item()*len(xb)
        if (ep+1) % PRINT_EVERY == 0:
            print(f"LSTM ep {ep+1}/{epochs} loss={total/len(dl.dataset):.6f}")

    model.eval()
    with torch.no_grad():
        Yhat = model(torch.from_numpy(Xte_seq).float().to(DEVICE)).cpu().numpy()

    if checkpoint_path is not None:
        try:
            os.makedirs(os.path.dirname(checkpoint_path), exist_ok=True)
            ckpt = {
                "state_dict": model.state_dict(),
                "config": {"input_dim": int(input_dim), "hidden": int(hidden), "out_dim": int(out_dim)},
                "meta": meta or {},
            }
            torch.save(ckpt, checkpoint_path)
            print(f"[checkpoint] saved: {checkpoint_path}")
        except Exception as e:
            print(f"[checkpoint] WARNING: failed to save {checkpoint_path}: {e}")

    if return_model:
        return Yte, Yhat, model
    return Yte, Yhat

# %% [markdown]
# ## 5) Neural GVAR (gated + static) — raw-scale metrics

# %%
class NeuralGVAR(nn.Module):
    def __init__(self, d, x_dim, lags, hidden=64, use_gating=True, use_concept=True):
        super().__init__()
        self.d=d; self.lags=lags; self.K=len(lags)
        self.use_gating=use_gating
        self.S = nn.Parameter(torch.randn(self.K,d,d)*0.01)
        self.gate = nn.Sequential(nn.Linear(x_dim, hidden), nn.ReLU(), nn.Linear(hidden, self.K*d*d)) if use_gating else None
        self.Wc = nn.Linear(x_dim, d, bias=False) if use_concept else None
        self.bias = nn.Parameter(torch.zeros(d))

    def forward(self, y_lags, x_t):
        B = y_lags.shape[0]
        if self.use_gating:
            g = self.gate(x_t).view(B,self.K,self.d,self.d)
            A = self.S[None,:,:,:] * torch.sigmoid(g)
        else:
            A = self.S[None,:,:,:].expand(B,-1,-1,-1)
        yhat = torch.zeros(B,self.d, device=y_lags.device)
        for ki in range(self.K):
            yk = y_lags[:,ki,:].unsqueeze(-1)
            yhat = yhat + torch.matmul(A[:,ki,:,:], yk).squeeze(-1)
        if self.Wc is not None:
            yhat = yhat + self.Wc(x_t)
        yhat = yhat + self.bias
        return yhat, A

def group_lasso_edges(S):
    return torch.sqrt(torch.sum(S**2, dim=0) + 1e-12).sum()

def temporal_smoothness(A_seq):
    return torch.mean((A_seq[1:] - A_seq[:-1])**2)

def fit_neural_gvar(full_train, full_test, y_cols, x_cols, horizon_h, use_gating=True, lam_sparse=5e-4, lam_smooth=1e-4, seed=0, checkpoint_path=None):
    torch.manual_seed(seed); np.random.seed(seed); random.seed(seed)

    target_cols = get_target_cols(y_cols, horizon_h)
    x_state_cols = [(sym, f"{feat}_t") for (sym, feat) in x_cols]

    Ytr_lags=[]
    for k in LAGS_HOURS:
        Ytr_lags.append(full_train[[(sym, f"{feat}_lag{k}") for (sym, feat) in y_cols]].to_numpy().astype(np.float32))
    Ytr_lags = np.stack(Ytr_lags, axis=1)
    Ytr = full_train[target_cols].to_numpy().astype(np.float32)
    Xtr = full_train[x_state_cols].to_numpy().astype(np.float32)

    Yte_lags=[]
    for k in LAGS_HOURS:
        Yte_lags.append(full_test[[(sym, f"{feat}_lag{k}") for (sym, feat) in y_cols]].to_numpy().astype(np.float32))
    Yte_lags = np.stack(Yte_lags, axis=1)
    Yte = full_test[target_cols].to_numpy().astype(np.float32)
    Xte = full_test[x_state_cols].to_numpy().astype(np.float32)

    Xmu, Xsd = Xtr.mean(0, keepdims=True), Xtr.std(0, keepdims=True) + 1e-6
    Xtr_s, Xte_s = (Xtr-Xmu)/Xsd, (Xte-Xmu)/Xsd

    Lmu = Ytr_lags.reshape(-1, Ytr_lags.shape[-1]).mean(0, keepdims=True)
    Lsd = Ytr_lags.reshape(-1, Ytr_lags.shape[-1]).std(0, keepdims=True) + 1e-6
    Ytr_lags_s, Yte_lags_s = (Ytr_lags-Lmu)/Lsd, (Yte_lags-Lmu)/Lsd

    y_mu, y_sd = Ytr.mean(0, keepdims=True), Ytr.std(0, keepdims=True) + 1e-6
    Ytr_s, Yte_s = (Ytr-y_mu)/y_sd, (Yte-y_mu)/y_sd

    d = Ytr.shape[1]; x_dim = Xtr.shape[1]
    hidden_dim = 64 if not FAST_MODE else 48
    model = NeuralGVAR(d, x_dim, LAGS_HOURS, hidden=hidden_dim, use_gating=use_gating, use_concept=True).to(DEVICE)
    opt = torch.optim.Adam(model.parameters(), lr=LR)
    loss_fn = nn.MSELoss()

    idx = np.arange(len(Ytr_s))
    dl = DataLoader(idx, batch_size=BATCH_SIZE, shuffle=False)

    model.train()
    for ep in range(EPOCHS):
        total=0.0
        for b_idx in dl:
            b = b_idx.numpy()
            y_lags = torch.from_numpy(Ytr_lags_s[b]).float().to(DEVICE)
            x_t = torch.from_numpy(Xtr_s[b]).float().to(DEVICE)
            y_true = torch.from_numpy(Ytr_s[b]).float().to(DEVICE)

            opt.zero_grad()
            y_pred, A = model(y_lags, x_t)
            loss = loss_fn(y_pred, y_true)
            loss = loss + lam_sparse * group_lasso_edges(model.S)
            if lam_smooth>0 and len(b)>1:
                loss = loss + lam_smooth * temporal_smoothness(A)
            loss.backward()
            opt.step()
            total += loss.item()*len(b)

        if (ep+1) % PRINT_EVERY == 0:
            print(f"NeuralGVAR({'gated' if use_gating else 'static'}) ep {ep+1}/{EPOCHS} loss={total/len(Ytr_s):.6f}")

    model.eval()
    with torch.no_grad():
        yhat_s_list=[]; A_list=[]
        for i in range(0, len(Yte_s), 2048):
            sl = slice(i, min(i+2048, len(Yte_s)))
            y_lags = torch.from_numpy(Yte_lags_s[sl]).float().to(DEVICE)
            x_t = torch.from_numpy(Xte_s[sl]).float().to(DEVICE)
            yhat_s, A = model(y_lags, x_t)
            yhat_s_list.append(yhat_s.cpu().numpy())
            A_list.append(A.cpu().numpy())
        Yhat_s = np.concatenate(yhat_s_list, axis=0)
        A_te = np.concatenate(A_list, axis=0)

    Yhat = Yhat_s * y_sd + y_mu
    metrics = {"MSE": mse(Yte, Yhat), "MAE": mae(Yte, Yhat), "SignHitRate": sign_hit(Yte, Yhat)}

    extras = {
        "A_test": A_te,
        "Wc": model.Wc.weight.detach().cpu().numpy(),
        "test_index": full_test.index.values,
        "x_state_cols": x_state_cols,
        "test_start": full_test.index.min(),
        "test_end": full_test.index.max(),
        "horizon_h": horizon_h
    }

    # ---- Optional checkpoint save (model + scalers + metadata) ----
    if checkpoint_path is not None:
        try:
            ckpt = {
                "model_class": "NeuralGVAR",
                "model_state_dict": model.state_dict(),
                "config": {
                    "d": int(d),
                    "x_dim": int(x_dim),
                    "lags_hours": list(LAGS_HOURS),
                    "hidden": int(hidden_dim),
                    "use_gating": bool(use_gating),
                    "use_concept": True,
                },
                "scalers": {
                    "Xmu": Xmu, "Xsd": Xsd,
                    "Lmu": Lmu, "Lsd": Lsd,
                    "y_mu": y_mu, "y_sd": y_sd,
                },
                "meta": {
                    "y_cols": y_cols,
                    "x_cols": x_cols,
                    "x_state_cols": x_state_cols,
                    "horizon_h": int(horizon_h),
                    "seed": int(seed),
                    "lam_sparse": float(lam_sparse),
                    "lam_smooth": float(lam_smooth),
                    "train_start": str(full_train.index.min()),
                    "train_end": str(full_train.index.max()),
                    "test_start": str(full_test.index.min()),
                    "test_end": str(full_test.index.max()),
                },
            }
            os.makedirs(str(Path(checkpoint_path).parent), exist_ok=True)
            torch.save(ckpt, checkpoint_path)
            print(f"[checkpoint] saved: {checkpoint_path}")
        except Exception as e:
            print(f"[checkpoint] WARNING: failed to save {checkpoint_path}: {e}")

    return metrics, extras


# --- StaticGVAR convenience wrapper (baseline) ---
# StaticGVAR = same architecture as NeuralGVAR but with gating disabled (A_k does not depend on x_t).
def fit_static_gvar(full_train, full_test, y_cols, x_cols, horizon_h,
                    lam_sparse=1e-3, seed=0):
    return fit_neural_gvar(full_train, full_test, y_cols, x_cols, horizon_h,
                           use_gating=False, lam_sparse=lam_sparse, lam_smooth=0.0, seed=seed)


# ---- Load helper: rebuild a (Neural/Static) GVAR from a saved checkpoint ----
def load_gvar_checkpoint(path, map_location=None):
    path = str(path)
    ckpt = torch.load(path, map_location=map_location if map_location is not None else DEVICE)
    cfg = ckpt["config"]
    model = NeuralGVAR(
        d=cfg["d"],
        x_dim=cfg["x_dim"],
        lags=cfg["lags_hours"],
        hidden=cfg["hidden"],
        use_gating=cfg["use_gating"],
        use_concept=cfg.get("use_concept", True),
    ).to(map_location if map_location is not None else DEVICE)
    model.load_state_dict(ckpt["model_state_dict"])
    model.eval()
    return model, ckpt

# %% [markdown]
# ## 6) Hypothesis + event utilities

# %%
def edge_timeseries(A_test, source_idx, target_idx):
    return A_test[:, :, target_idx, source_idx].sum(axis=1)

def edge_stats_with_ci(A_test, source_sym, target_sym, block_size=48, n_boot=400):
    e = edge_timeseries(A_test, ASSET_IDX[source_sym], ASSET_IDX[target_sym])
    sf = float(np.mean(e > 0))
    med = float(np.median(e))
    sf_lo, sf_hi = block_bootstrap_ci(np.asarray(e), lambda z: np.mean(z > 0), block_size, n_boot=n_boot, seed=0)
    med_lo, med_hi = block_bootstrap_ci(np.asarray(e), lambda z: np.median(z), block_size, n_boot=n_boot, seed=1)
    return sf, sf_lo, sf_hi, med, med_lo, med_hi

def diag_concept_weight(extras, concept_feat_base: str, asset: str) -> float:
    Wc = extras["Wc"]
    cols = extras["x_state_cols"]
    col_index = {c:i for i,c in enumerate(cols)}
    key = (asset, f"{concept_feat_base}_t")
    if key not in col_index:
        return np.nan
    return float(Wc[ASSET_IDX[asset], col_index[key]])

def conditioning_delta_on_test(test_df: pd.DataFrame, horizon_h: int, concept_feat: str, y_feat: str, q: float, mode: str):
    out={}
    for a in SYMBOLS:
        concept = test_df[(a, concept_feat)].astype(float)
        y_next  = test_df[(a, y_feat)].shift(-horizon_h).astype(float)
        df = pd.concat([concept, y_next], axis=1).dropna()
        if len(df) == 0:
            out[a] = np.nan
            continue
        if mode == "abs":
            thr = df.iloc[:,0].abs().quantile(q)
            mask = df.iloc[:,0].abs() >= thr
        else:
            thr = df.iloc[:,0].quantile(q)
            mask = df.iloc[:,0] >= thr
        out[a] = float(df.loc[mask].iloc[:,1].mean() - df.iloc[:,1].mean())
    return out

def define_events(series: pd.Series, q=0.99, mode="abs"):
    if mode=="abs":
        thr = series.abs().quantile(q)
        ev = series.index[series.abs()>=thr]
    else:
        thr = series.quantile(q)
        ev = series.index[series>=thr]
    return pd.DatetimeIndex(ev), float(thr)

def event_pre_post_delta(e_series: pd.Series, events: pd.DatetimeIndex, pre=6, post=6):
    deltas=[]
    for t in events:
        pre_win = e_series.loc[t - pd.Timedelta(hours=pre): t - pd.Timedelta(hours=1)]
        post_win = e_series.loc[t + pd.Timedelta(hours=1): t + pd.Timedelta(hours=post)]
        if len(pre_win)==0 or len(post_win)==0:
            continue
        deltas.append(post_win.abs().mean() - pre_win.abs().mean())
    return np.array(deltas)

def matched_control_events(events, match_stat: pd.Series, exclude, n_bins=10, seed=0):
    rng = np.random.default_rng(seed)
    ms = match_stat.dropna()
    excl=set()
    for t in exclude:
        for h in range(-EVENT_PRE_H, EVENT_POST_H+1):
            excl.add(t + pd.Timedelta(hours=h))
    ms_valid = ms.loc[~ms.index.isin(list(excl))]
    if len(ms_valid) < 10:
        return pd.DatetimeIndex([])
    bins = pd.qcut(ms_valid, q=n_bins, duplicates="drop")
    bin_by_time = pd.Series(bins.astype(str).values, index=ms_valid.index)

    controls=[]
    for t in events:
        if t not in ms.index:
            continue
        nearest = ms_valid.index.get_indexer([t], method="nearest")[0]
        b = bin_by_time.iloc[nearest]
        cand = bin_by_time[bin_by_time==b].index
        if len(cand)==0:
            continue
        controls.append(rng.choice(cand))
    return pd.DatetimeIndex(controls)

def placebo_shift(events, hours=-6):
    return pd.DatetimeIndex([t + pd.Timedelta(hours=hours) for t in events])

def random_events(index: pd.DatetimeIndex, n: int, seed=0):
    rng = np.random.default_rng(seed)
    idx = rng.choice(np.arange(len(index)), size=min(n, len(index)), replace=False)
    return pd.DatetimeIndex(index[idx])

# %% [markdown]
# ## 7) Run experiments

# %%
def load_varx_checkpoint(path):
    import joblib
    ckpt = joblib.load(path)
    return ckpt["model"], ckpt["scaler"], ckpt.get("meta", {})

def load_lstm_checkpoint(path, map_location="cpu"):
    ckpt = torch.load(path, map_location=map_location)
    cfg = ckpt["config"]
    m = CompactLSTM(input_dim=cfg["input_dim"], hidden=cfg["hidden"], out_dim=cfg["out_dim"]).to(DEVICE)
    m.load_state_dict(ckpt["state_dict"])
    m.eval()
    return m, ckpt.get("meta", {})

def _compat_lags(meta_or_cfg, expected_lags):
    lags = None
    if isinstance(meta_or_cfg, dict):
        lags = meta_or_cfg.get("lags_hours") or meta_or_cfg.get("lags")
    if lags is None:
        return True
    return list(lags) == list(expected_lags)

def _compat_horizon(meta_or_cfg, expected_h):
    h = None
    if isinstance(meta_or_cfg, dict):
        h = meta_or_cfg.get("horizon_h") or meta_or_cfg.get("h")
    if h is None:
        return True
    return int(h) == int(expected_h)

def _predict_varx_from_checkpoint(path, full_test, y_cols, horizon_h):
    model, scaler, meta = load_varx_checkpoint(path)
    if not _compat_horizon(meta, horizon_h):
        raise ValueError(f"VARX checkpoint horizon mismatch: {meta.get('horizon_h', meta.get('h'))} != {horizon_h}")
    target_cols = get_target_cols(y_cols, horizon_h)
    Xte = full_test.drop(columns=target_cols).to_numpy()
    Yte = full_test[target_cols].to_numpy()
    Xte_s = scaler.transform(Xte)
    Yhat = model.predict(Xte_s)
    return Yte, Yhat

def _predict_lstm_from_checkpoint(path, full_test, y_cols, x_cols, lags_h, horizon_h):
    model, meta = load_lstm_checkpoint(path, map_location=DEVICE)
    if not _compat_horizon(meta, horizon_h):
        raise ValueError(f"LSTM checkpoint horizon mismatch: {meta.get('horizon_h', meta.get('h'))} != {horizon_h}")
    Xte_seq, Yte = build_seq(full_test, y_cols, x_cols, lags_h, horizon_h)
    with torch.no_grad():
        Yhat = model(torch.from_numpy(Xte_seq).float().to(DEVICE)).cpu().numpy()
    return Yte, Yhat

def _predict_gvar_from_checkpoint(path, full_test, y_cols, x_cols, horizon_h):
    model, ckpt = load_gvar_checkpoint(path, map_location=DEVICE)
    cfg = ckpt.get("config", {})
    meta = ckpt.get("meta", {})
    if not _compat_lags(cfg, LAGS_HOURS):
        raise ValueError(f"GVAR checkpoint lag mismatch: {cfg.get('lags_hours')} != {list(LAGS_HOURS)}")
    if not _compat_horizon(meta, horizon_h):
        raise ValueError(f"GVAR checkpoint horizon mismatch: {meta.get('horizon_h', meta.get('h'))} != {horizon_h}")
    scalers = ckpt["scalers"]

    target_cols = get_target_cols(y_cols, horizon_h)
    x_state_cols = [(sym, f"{feat}_t") for (sym, feat) in x_cols]

    Yte_lags = []
    for k in LAGS_HOURS:
        Yte_lags.append(full_test[[(sym, f"{feat}_lag{k}") for (sym, feat) in y_cols]].to_numpy().astype(np.float32))
    Yte_lags = np.stack(Yte_lags, axis=1)
    Yte = full_test[target_cols].to_numpy().astype(np.float32)
    Xte = full_test[x_state_cols].to_numpy().astype(np.float32)

    Xte_s = (Xte - scalers["Xmu"]) / scalers["Xsd"]
    Yte_lags_s = (Yte_lags - scalers["Lmu"]) / scalers["Lsd"]

    model.eval()
    with torch.no_grad():
        yhat_s_list = []
        A_list = []
        for i in range(0, len(Yte_lags_s), 2048):
            sl = slice(i, min(i + 2048, len(Yte_lags_s)))
            y_lags = torch.from_numpy(Yte_lags_s[sl]).float().to(DEVICE)
            x_t = torch.from_numpy(Xte_s[sl]).float().to(DEVICE)
            yhat_s, A = model(y_lags, x_t)
            yhat_s_list.append(yhat_s.cpu().numpy())
            A_list.append(A.cpu().numpy())
        Yhat_s = np.concatenate(yhat_s_list, axis=0)
        A_te = np.concatenate(A_list, axis=0)

    Yhat = Yhat_s * scalers["y_sd"] + scalers["y_mu"]

    extras = {
        "A_test": A_te,
        "Wc": model.Wc.weight.detach().cpu().numpy() if model.Wc is not None else None,
        "test_index": full_test.index.values,
        "x_state_cols": x_state_cols,
        "test_start": full_test.index.min(),
        "test_end": full_test.index.max(),
        "horizon_h": horizon_h,
    }
    return Yte, Yhat, extras

def run_one(task: TaskSpec, tr_s, tr_e, te_s, te_e, seed, lam_sparse):
    full = make_design_matrix(panel, task.y_cols, task.x_cols, LAGS_HOURS, task.horizon_h)
    tr, te = split_time(full, tr_s, tr_e, te_s, te_e)
    if len(tr) < 2000 or len(te) < 500:
        raise ValueError(f"too little data: train={len(tr)} test={len(te)}")

    # ---- checkpoint paths (optional; per-model folders) ----
    ckpt_paths = {}
    meta = {
        "task": task.name,
        "h": int(task.horizon_h),
        "train_start": str(tr_s),
        "train_end": str(tr_e),
        "test_start": str(te_s),
        "test_end": str(te_e),
        "seed": int(seed),
        "lam_sparse": float(lam_sparse),
        "lags_hours": list(LAGS_HOURS),
    }
    if 'SAVE_CHECKPOINTS' in globals() and SAVE_CHECKPOINTS:
        tr_tag = str(tr_s).replace(':','-')
        te_tag = str(te_s).replace(':','-')
        run_id = f"{task.name}_h{task.horizon_h}_tr{tr_tag}_te{te_tag}_seed{seed}_lam{lam_sparse:.1e}"

        ckpt_paths["Last"] = str(MODEL_CKPT_DIRS["Last"] / f"{run_id}.json")
        ckpt_paths["VARX-LASSO"] = str(MODEL_CKPT_DIRS["VARX_LASSO"] / f"{run_id}.pkl")
        ckpt_paths["LSTM"] = str(MODEL_CKPT_DIRS["LSTM"] / f"{run_id}.pt")
        ckpt_paths["NeuralGVAR"] = str(MODEL_CKPT_DIRS["NeuralGVAR"] / f"{run_id}.pt")
        ckpt_paths["StaticGVAR"] = str(MODEL_CKPT_DIRS["StaticGVAR"] / f"{run_id}.pt")

    # ---- Last baseline (deterministic) ----
    Y_last, Yhat_last = run_last(te, task.y_cols, task.horizon_h)
    m_last = {"MSE": mse(Y_last, Yhat_last), "MAE": mae(Y_last, Yhat_last), "SignHitRate": sign_hit(Y_last, Yhat_last)}
    if "Last" in ckpt_paths:
        try:
            import json, os
            os.makedirs(os.path.dirname(ckpt_paths["Last"]), exist_ok=True)
            with open(ckpt_paths["Last"], "w") as f:
                json.dump({"type": "Last", "meta": meta, "metrics": m_last}, f, indent=2)
            print(f"[checkpoint] saved: {ckpt_paths['Last']}")
        except Exception as e:
            print(f"[checkpoint] WARNING: failed to save {ckpt_paths['Last']}: {e}")

    # ---- VARX-LASSO baseline ----
    varx_ckpt = ckpt_paths.get("VARX-LASSO")
    if varx_ckpt and Path(varx_ckpt).exists():
        print(f"[checkpoint] loading: {varx_ckpt}")
        try:
            Y_varx, Yhat_varx = _predict_varx_from_checkpoint(varx_ckpt, te, task.y_cols, task.horizon_h)
        except ValueError as e:
            print(f"[checkpoint] warning: {e}; retraining VARX-LASSO")
            Y_varx, Yhat_varx = fit_varx_lasso(
                tr, te, task.y_cols, task.horizon_h,
                checkpoint_path=varx_ckpt,
                meta=meta,
            )
    else:
        Y_varx, Yhat_varx = fit_varx_lasso(
            tr, te, task.y_cols, task.horizon_h,
            checkpoint_path=varx_ckpt,
            meta=meta,
        )
    m_varx = {"MSE": mse(Y_varx, Yhat_varx), "MAE": mae(Y_varx, Yhat_varx), "SignHitRate": sign_hit(Y_varx, Yhat_varx)}

    # ---- LSTM baseline ----
    lstm_ckpt = ckpt_paths.get("LSTM")
    if lstm_ckpt and Path(lstm_ckpt).exists():
        print(f"[checkpoint] loading: {lstm_ckpt}")
        try:
            Y_lstm, Yhat_lstm = _predict_lstm_from_checkpoint(lstm_ckpt, te, task.y_cols, task.x_cols, LAGS_HOURS, task.horizon_h)
        except ValueError as e:
            print(f"[checkpoint] warning: {e}; retraining LSTM")
            Y_lstm, Yhat_lstm = fit_compact_lstm(
                tr, te, task.y_cols, task.x_cols, LAGS_HOURS, task.horizon_h,
                epochs=12 if not FAST_MODE else 5, seed=seed,
                hidden=32 if not FAST_MODE else 24,
                checkpoint_path=lstm_ckpt,
                meta=meta,
            )
    else:
        Y_lstm, Yhat_lstm = fit_compact_lstm(
            tr, te, task.y_cols, task.x_cols, LAGS_HOURS, task.horizon_h,
            epochs=12 if not FAST_MODE else 5, seed=seed,
            hidden=32 if not FAST_MODE else 24,
            checkpoint_path=lstm_ckpt,
            meta=meta,
        )
    m_lstm = {"MSE": mse(Y_lstm, Yhat_lstm), "MAE": mae(Y_lstm, Yhat_lstm), "SignHitRate": sign_hit(Y_lstm, Yhat_lstm)}

    # ---- NeuralGVAR + StaticGVAR ----
    ng_ckpt = ckpt_paths.get("NeuralGVAR")
    if ng_ckpt and Path(ng_ckpt).exists():
        print(f"[checkpoint] loading: {ng_ckpt}")
        try:
            Y_ng, Yhat_ng, ex_ng = _predict_gvar_from_checkpoint(ng_ckpt, te, task.y_cols, task.x_cols, task.horizon_h)
            m_ng = {"MSE": mse(Y_ng, Yhat_ng), "MAE": mae(Y_ng, Yhat_ng), "SignHitRate": sign_hit(Y_ng, Yhat_ng)}
        except ValueError as e:
            print(f"[checkpoint] warning: {e}; retraining NeuralGVAR")
            m_ng, ex_ng = fit_neural_gvar(
                tr, te, task.y_cols, task.x_cols, task.horizon_h,
                use_gating=True, lam_sparse=lam_sparse, lam_smooth=1e-4, seed=seed,
                checkpoint_path=ng_ckpt,
            )
    else:
        m_ng, ex_ng = fit_neural_gvar(
            tr, te, task.y_cols, task.x_cols, task.horizon_h,
            use_gating=True, lam_sparse=lam_sparse, lam_smooth=1e-4, seed=seed,
            checkpoint_path=ng_ckpt,
        )

    static_ckpt = ckpt_paths.get("StaticGVAR")
    if static_ckpt and Path(static_ckpt).exists():
        print(f"[checkpoint] loading: {static_ckpt}")
        try:
            Y_static, Yhat_static, ex_static = _predict_gvar_from_checkpoint(static_ckpt, te, task.y_cols, task.x_cols, task.horizon_h)
            m_static = {"MSE": mse(Y_static, Yhat_static), "MAE": mae(Y_static, Yhat_static), "SignHitRate": sign_hit(Y_static, Yhat_static)}
        except ValueError as e:
            print(f"[checkpoint] warning: {e}; retraining StaticGVAR")
            m_static, ex_static = fit_neural_gvar(
                tr, te, task.y_cols, task.x_cols, task.horizon_h,
                use_gating=False, lam_sparse=lam_sparse, lam_smooth=0.0, seed=seed,
                checkpoint_path=static_ckpt,
            )
    else:
        m_static, ex_static = fit_neural_gvar(
            tr, te, task.y_cols, task.x_cols, task.horizon_h,
            use_gating=False, lam_sparse=lam_sparse, lam_smooth=0.0, seed=seed,
            checkpoint_path=static_ckpt,
        )

    return {
        "task": task.name, "h": task.horizon_h,
        "train_start": tr_s, "train_end": tr_e,
        "test_start": te_s, "test_end": te_e,
        "seed": seed, "lam_sparse": lam_sparse,
        "metrics": {"Last": m_last, "VARX-LASSO": m_varx, "LSTM": m_lstm, "NeuralGVAR": m_ng, "StaticGVAR": m_static},
        "extras": {"NeuralGVAR": ex_ng, "StaticGVAR": ex_static},
        "checkpoint_paths": ckpt_paths,
    }

results=[]
for tr_s, tr_e, te_s, te_e in BACKTEST_WINDOWS:
    for task in (RET_TASKS + VOL_TASKS):
        for lam in LAMBDA_SPARSE_SWEEP:
            for seed in SEEDS:
                print("\n====", task.name, (tr_s,tr_e,"->",te_s,te_e), "seed", seed, "lam", lam, "====")
                results.append(run_one(task, tr_s, tr_e, te_s, te_e, seed, lam))

print("Runs completed:", len(results))
# Out:
# ==== RET_h1 ('2021-01-01', '2022-12-31 23:00', '->', '2023-01-01', '2023-12-31 23:00') seed 1 lam 0.0001 ====
# [checkpoint] saved: checkpoints/Last/RET_h1_h1_tr2021-01-01_te2023-01-01_seed1_lam1.0e-04.json
# [checkpoint] saved: checkpoints/VARX_LASSO/RET_h1_h1_tr2021-01-01_te2023-01-01_seed1_lam1.0e-04.pkl
# LSTM ep 1/12 loss=0.000891
# LSTM ep 2/12 loss=0.000152
# LSTM ep 3/12 loss=0.000152
# LSTM ep 4/12 loss=0.000152
# LSTM ep 5/12 loss=0.000152
# LSTM ep 6/12 loss=0.000151
# LSTM ep 7/12 loss=0.000152
# LSTM ep 8/12 loss=0.000152
# LSTM ep 9/12 loss=0.000152
# LSTM ep 10/12 loss=0.000152
# LSTM ep 11/12 loss=0.000152
# LSTM ep 12/12 loss=0.000152
# [checkpoint] saved: checkpoints/LSTM/RET_h1_h1_tr2021-01-01_te2023-01-01_seed1_lam1.0e-04.pt
# NeuralGVAR(gated) ep 1/25 loss=1.321641
# NeuralGVAR(gated) ep 2/25 loss=1.147918
# NeuralGVAR(gated) ep 3/25 loss=1.063271
# NeuralGVAR(gated) ep 4/25 loss=1.025690
# NeuralGVAR(gated) ep 5/25 loss=1.008858
# NeuralGVAR(gated) ep 6/25 loss=1.001040
# NeuralGVAR(gated) ep 7/25 loss=0.996971
# NeuralGVAR(gated) ep 8/25 loss=0.994530
# NeuralGVAR(gated) ep 9/25 loss=0.992984
# NeuralGVAR(gated) ep 10/25 loss=0.991491
# NeuralGVAR(gated) ep 11/25 loss=0.990273
# NeuralGVAR(gated) ep 12/25 loss=0.989246
# NeuralGVAR(gated) ep 13/25 loss=0.988304
# NeuralGVAR(gated) ep 14/25 loss=0.987555
# NeuralGVAR(gated) ep 15/25 loss=0.986413
# NeuralGVAR(gated) ep 16/25 loss=0.986339
# NeuralGVAR(gated) ep 17/25 loss=0.985307
# NeuralGVAR(gated) ep 18/25 loss=0.984605
# NeuralGVAR(gated) ep 19/25 loss=0.983803
# NeuralGVAR(gated) ep 20/25 loss=0.983356
# NeuralGVAR(gated) ep 21/25 loss=0.982942
# NeuralGVAR(gated) ep 22/25 loss=0.982646
# NeuralGVAR(gated) ep 23/25 loss=0.982096
# NeuralGVAR(gated) ep 24/25 loss=0.981204
# NeuralGVAR(gated) ep 25/25 loss=0.981067
# [checkpoint] saved: checkpoints/NeuralGVAR/RET_h1_h1_tr2021-01-01_te2023-01-01_seed1_lam1.0e-04.pt
# NeuralGVAR(static) ep 1/25 loss=1.333047
# NeuralGVAR(static) ep 2/25 loss=1.182794
# NeuralGVAR(static) ep 3/25 loss=1.100086
# NeuralGVAR(static) ep 4/25 loss=1.055271
# NeuralGVAR(static) ep 5/25 loss=1.031406
# NeuralGVAR(static) ep 6/25 loss=1.018585
# NeuralGVAR(static) ep 7/25 loss=1.011562
# NeuralGVAR(static) ep 8/25 loss=1.007589
# NeuralGVAR(static) ep 9/25 loss=1.005216
# NeuralGVAR(static) ep 10/25 loss=1.003696
# NeuralGVAR(static) ep 11/25 loss=1.002658
# NeuralGVAR(static) ep 12/25 loss=1.001916
# NeuralGVAR(static) ep 13/25 loss=1.001371
# NeuralGVAR(static) ep 14/25 loss=1.000964
# NeuralGVAR(static) ep 15/25 loss=1.000656
# NeuralGVAR(static) ep 16/25 loss=1.000420
# NeuralGVAR(static) ep 17/25 loss=1.000238
# NeuralGVAR(static) ep 18/25 loss=1.000096
# NeuralGVAR(static) ep 19/25 loss=0.999986
# NeuralGVAR(static) ep 20/25 loss=0.999901
# NeuralGVAR(static) ep 21/25 loss=0.999834
# NeuralGVAR(static) ep 22/25 loss=0.999784
# NeuralGVAR(static) ep 23/25 loss=0.999746
# NeuralGVAR(static) ep 24/25 loss=0.999719
# NeuralGVAR(static) ep 25/25 loss=0.999700
# [checkpoint] saved: checkpoints/StaticGVAR/RET_h1_h1_tr2021-01-01_te2023-01-01_seed1_lam1.0e-04.pt
#
# ==== RET_h1 ('2021-01-01', '2022-12-31 23:00', '->', '2023-01-01', '2023-12-31 23:00') seed 2 lam 0.0001 ====
# [checkpoint] saved: checkpoints/Last/RET_h1_h1_tr2021-01-01_te2023-01-01_seed2_lam1.0e-04.json
# [checkpoint] saved: checkpoints/VARX_LASSO/RET_h1_h1_tr2021-01-01_te2023-01-01_seed2_lam1.0e-04.pkl
# LSTM ep 1/12 loss=0.000802
# LSTM ep 2/12 loss=0.000152
# LSTM ep 3/12 loss=0.000152
# LSTM ep 4/12 loss=0.000152
# LSTM ep 5/12 loss=0.000152
# LSTM ep 6/12 loss=0.000152
# LSTM ep 7/12 loss=0.000153
# LSTM ep 8/12 loss=0.000152
# LSTM ep 9/12 loss=0.000152
# LSTM ep 10/12 loss=0.000152
# LSTM ep 11/12 loss=0.000152
# LSTM ep 12/12 loss=0.000153
# [checkpoint] saved: checkpoints/LSTM/RET_h1_h1_tr2021-01-01_te2023-01-01_seed2_lam1.0e-04.pt
# NeuralGVAR(gated) ep 1/25 loss=1.304611
# NeuralGVAR(gated) ep 2/25 loss=1.163783
# NeuralGVAR(gated) ep 3/25 loss=1.092519
# NeuralGVAR(gated) ep 4/25 loss=1.055530
# NeuralGVAR(gated) ep 5/25 loss=1.034782
# NeuralGVAR(gated) ep 6/25 loss=1.021984
# NeuralGVAR(gated) ep 7/25 loss=1.013668
# NeuralGVAR(gated) ep 8/25 loss=1.007976
# NeuralGVAR(gated) ep 9/25 loss=1.003657
# NeuralGVAR(gated) ep 10/25 loss=1.000434
# NeuralGVAR(gated) ep 11/25 loss=0.997699
# NeuralGVAR(gated) ep 12/25 loss=0.995463
# NeuralGVAR(gated) ep 13/25 loss=0.993505
# NeuralGVAR(gated) ep 14/25 loss=0.991698
# NeuralGVAR(gated) ep 15/25 loss=0.990069
# NeuralGVAR(gated) ep 16/25 loss=0.988651
# NeuralGVAR(gated) ep 17/25 loss=0.987299
# NeuralGVAR(gated) ep 18/25 loss=0.986176
# NeuralGVAR(gated) ep 19/25 loss=0.985006
# NeuralGVAR(gated) ep 20/25 loss=0.984047
# NeuralGVAR(gated) ep 21/25 loss=0.983233
# NeuralGVAR(gated) ep 22/25 loss=0.982339
# NeuralGVAR(gated) ep 23/25 loss=0.981502
# NeuralGVAR(gated) ep 24/25 loss=0.980435
# NeuralGVAR(gated) ep 25/25 loss=0.979517
# [checkpoint] saved: checkpoints/NeuralGVAR/RET_h1_h1_tr2021-01-01_te2023-01-01_seed2_lam1.0e-04.pt
# NeuralGVAR(static) ep 1/25 loss=1.233277
# NeuralGVAR(static) ep 2/25 loss=1.130601
# NeuralGVAR(static) ep 3/25 loss=1.083015
# NeuralGVAR(static) ep 4/25 loss=1.055908
# NeuralGVAR(static) ep 5/25 loss=1.039061
# NeuralGVAR(static) ep 6/25 loss=1.027964
# NeuralGVAR(static) ep 7/25 loss=1.020354
# NeuralGVAR(static) ep 8/25 loss=1.014985
# NeuralGVAR(static) ep 9/25 loss=1.011125
# NeuralGVAR(static) ep 10/25 loss=1.008313
# NeuralGVAR(static) ep 11/25 loss=1.006245
# NeuralGVAR(static) ep 12/25 loss=1.004712
# NeuralGVAR(static) ep 13/25 loss=1.003567
# NeuralGVAR(static) ep 14/25 loss=1.002705
# NeuralGVAR(static) ep 15/25 loss=1.002051
# NeuralGVAR(static) ep 16/25 loss=1.001551
# NeuralGVAR(static) ep 17/25 loss=1.001167
# NeuralGVAR(static) ep 18/25 loss=1.000868
# NeuralGVAR(static) ep 19/25 loss=1.000635
# NeuralGVAR(static) ep 20/25 loss=1.000451
# NeuralGVAR(static) ep 21/25 loss=1.000305
# NeuralGVAR(static) ep 22/25 loss=1.000189
# NeuralGVAR(static) ep 23/25 loss=1.000097
# NeuralGVAR(static) ep 24/25 loss=1.000023
# NeuralGVAR(static) ep 25/25 loss=0.999965
# [checkpoint] saved: checkpoints/StaticGVAR/RET_h1_h1_tr2021-01-01_te2023-01-01_seed2_lam1.0e-04.pt
#
# ==== RET_h1 ('2021-01-01', '2022-12-31 23:00', '->', '2023-01-01', '2023-12-31 23:00') seed 3 lam 0.0001 ====
# [checkpoint] saved: checkpoints/Last/RET_h1_h1_tr2021-01-01_te2023-01-01_seed3_lam1.0e-04.json
# [checkpoint] saved: checkpoints/VARX_LASSO/RET_h1_h1_tr2021-01-01_te2023-01-01_seed3_lam1.0e-04.pkl
# LSTM ep 1/12 loss=0.000594
# LSTM ep 2/12 loss=0.000153
# LSTM ep 3/12 loss=0.000152
# LSTM ep 4/12 loss=0.000153
# LSTM ep 5/12 loss=0.000152
# LSTM ep 6/12 loss=0.000153
# LSTM ep 7/12 loss=0.000152
# LSTM ep 8/12 loss=0.000153
# LSTM ep 9/12 loss=0.000154
# LSTM ep 10/12 loss=0.000152
# LSTM ep 11/12 loss=0.000153
# LSTM ep 12/12 loss=0.000152
# [checkpoint] saved: checkpoints/LSTM/RET_h1_h1_tr2021-01-01_te2023-01-01_seed3_lam1.0e-04.pt
# NeuralGVAR(gated) ep 1/25 loss=1.160815
# NeuralGVAR(gated) ep 2/25 loss=1.078682
# NeuralGVAR(gated) ep 3/25 loss=1.049924
# NeuralGVAR(gated) ep 4/25 loss=1.035708
# NeuralGVAR(gated) ep 5/25 loss=1.026066
# NeuralGVAR(gated) ep 6/25 loss=1.018431
# NeuralGVAR(gated) ep 7/25 loss=1.011902
# NeuralGVAR(gated) ep 8/25 loss=1.006553
# NeuralGVAR(gated) ep 9/25 loss=1.002273
# NeuralGVAR(gated) ep 10/25 loss=0.998573
# NeuralGVAR(gated) ep 11/25 loss=0.995663
# NeuralGVAR(gated) ep 12/25 loss=0.993421
# NeuralGVAR(gated) ep 13/25 loss=0.991394
# NeuralGVAR(gated) ep 14/25 loss=0.989745
# NeuralGVAR(gated) ep 15/25 loss=0.988114
# NeuralGVAR(gated) ep 16/25 loss=0.986959
# NeuralGVAR(gated) ep 17/25 loss=0.985629
# NeuralGVAR(gated) ep 18/25 loss=0.984909
# NeuralGVAR(gated) ep 19/25 loss=0.983792
# NeuralGVAR(gated) ep 20/25 loss=0.982742
# NeuralGVAR(gated) ep 21/25 loss=0.982097
# NeuralGVAR(gated) ep 22/25 loss=0.981972
# NeuralGVAR(gated) ep 23/25 loss=0.980808
# NeuralGVAR(gated) ep 24/25 loss=0.979916
# NeuralGVAR(gated) ep 25/25 loss=0.979503
# [checkpoint] saved: checkpoints/NeuralGVAR/RET_h1_h1_tr2021-01-01_te2023-01-01_seed3_lam1.0e-04.pt
# NeuralGVAR(static) ep 1/25 loss=1.215682
# NeuralGVAR(static) ep 2/25 loss=1.093432
# NeuralGVAR(static) ep 3/25 loss=1.043884
# NeuralGVAR(static) ep 4/25 loss=1.025219
# NeuralGVAR(static) ep 5/25 loss=1.017184
# NeuralGVAR(static) ep 6/25 loss=1.012476
# NeuralGVAR(static) ep 7/25 loss=1.009113
# NeuralGVAR(static) ep 8/25 loss=1.006574
# NeuralGVAR(static) ep 9/25 loss=1.004652
# NeuralGVAR(static) ep 10/25 loss=1.003212
# NeuralGVAR(static) ep 11/25 loss=1.002149
# NeuralGVAR(static) ep 12/25 loss=1.001378
# NeuralGVAR(static) ep 13/25 loss=1.000827
# NeuralGVAR(static) ep 14/25 loss=1.000442
# NeuralGVAR(static) ep 15/25 loss=1.000176
# NeuralGVAR(static) ep 16/25 loss=0.999997
# NeuralGVAR(static) ep 17/25 loss=0.999877
# NeuralGVAR(static) ep 18/25 loss=0.999799
# NeuralGVAR(static) ep 19/25 loss=0.999750
# NeuralGVAR(static) ep 20/25 loss=0.999719
# NeuralGVAR(static) ep 21/25 loss=0.999702
# NeuralGVAR(static) ep 22/25 loss=0.999694
# NeuralGVAR(static) ep 23/25 loss=0.999692
# NeuralGVAR(static) ep 24/25 loss=0.999694
# NeuralGVAR(static) ep 25/25 loss=0.999699
# [checkpoint] saved: checkpoints/StaticGVAR/RET_h1_h1_tr2021-01-01_te2023-01-01_seed3_lam1.0e-04.pt
#
# ==== RET_h1 ('2021-01-01', '2022-12-31 23:00', '->', '2023-01-01', '2023-12-31 23:00') seed 4 lam 0.0001 ====
# [checkpoint] saved: checkpoints/Last/RET_h1_h1_tr2021-01-01_te2023-01-01_seed4_lam1.0e-04.json
# [checkpoint] saved: checkpoints/VARX_LASSO/RET_h1_h1_tr2021-01-01_te2023-01-01_seed4_lam1.0e-04.pkl
# LSTM ep 1/12 loss=0.001923
# LSTM ep 2/12 loss=0.000152
# LSTM ep 3/12 loss=0.000152
# LSTM ep 4/12 loss=0.000152
# LSTM ep 5/12 loss=0.000152
# LSTM ep 6/12 loss=0.000152
# LSTM ep 7/12 loss=0.000152
# LSTM ep 8/12 loss=0.000152
# LSTM ep 9/12 loss=0.000152
# LSTM ep 10/12 loss=0.000152
# LSTM ep 11/12 loss=0.000152
# LSTM ep 12/12 loss=0.000152
# [checkpoint] saved: checkpoints/LSTM/RET_h1_h1_tr2021-01-01_te2023-01-01_seed4_lam1.0e-04.pt
# NeuralGVAR(gated) ep 1/25 loss=1.310872
# NeuralGVAR(gated) ep 2/25 loss=1.165730
# NeuralGVAR(gated) ep 3/25 loss=1.085876
# NeuralGVAR(gated) ep 4/25 loss=1.045320
# NeuralGVAR(gated) ep 5/25 loss=1.024862
# NeuralGVAR(gated) ep 6/25 loss=1.013641
# NeuralGVAR(gated) ep 7/25 loss=1.006316
# NeuralGVAR(gated) ep 8/25 loss=1.001435
# NeuralGVAR(gated) ep 9/25 loss=0.997609
# NeuralGVAR(gated) ep 10/25 loss=0.994681
# NeuralGVAR(gated) ep 11/25 loss=0.992334
# NeuralGVAR(gated) ep 12/25 loss=0.990827
# NeuralGVAR(gated) ep 13/25 loss=0.988873
# NeuralGVAR(gated) ep 14/25 loss=0.987774
# NeuralGVAR(gated) ep 15/25 loss=0.986595
# NeuralGVAR(gated) ep 16/25 loss=0.985867
# NeuralGVAR(gated) ep 17/25 loss=0.985009
# NeuralGVAR(gated) ep 18/25 loss=0.983971
# NeuralGVAR(gated) ep 19/25 loss=0.983370
# NeuralGVAR(gated) ep 20/25 loss=0.982982
# NeuralGVAR(gated) ep 21/25 loss=0.982493
# NeuralGVAR(gated) ep 22/25 loss=0.981389
# NeuralGVAR(gated) ep 23/25 loss=0.981186
# NeuralGVAR(gated) ep 24/25 loss=0.980721
# NeuralGVAR(gated) ep 25/25 loss=0.980253
# [checkpoint] saved: checkpoints/NeuralGVAR/RET_h1_h1_tr2021-01-01_te2023-01-01_seed4_lam1.0e-04.pt
# NeuralGVAR(static) ep 1/25 loss=1.258586
# NeuralGVAR(static) ep 2/25 loss=1.130661
# NeuralGVAR(static) ep 3/25 loss=1.066900
# NeuralGVAR(static) ep 4/25 loss=1.037464
# NeuralGVAR(static) ep 5/25 loss=1.024159
# NeuralGVAR(static) ep 6/25 loss=1.017279
# NeuralGVAR(static) ep 7/25 loss=1.012867
# NeuralGVAR(static) ep 8/25 loss=1.009615
# NeuralGVAR(static) ep 9/25 loss=1.007124
# NeuralGVAR(static) ep 10/25 loss=1.005225
# NeuralGVAR(static) ep 11/25 loss=1.003796
# NeuralGVAR(static) ep 12/25 loss=1.002733
# NeuralGVAR(static) ep 13/25 loss=1.001947
# NeuralGVAR(static) ep 14/25 loss=1.001366
# NeuralGVAR(static) ep 15/25 loss=1.000937
# NeuralGVAR(static) ep 16/25 loss=1.000617
# NeuralGVAR(static) ep 17/25 loss=1.000379
# NeuralGVAR(static) ep 18/25 loss=1.000200
# NeuralGVAR(static) ep 19/25 loss=1.000065
# NeuralGVAR(static) ep 20/25 loss=0.999964
# NeuralGVAR(static) ep 21/25 loss=0.999888
# NeuralGVAR(static) ep 22/25 loss=0.999833
# NeuralGVAR(static) ep 23/25 loss=0.999792
# NeuralGVAR(static) ep 24/25 loss=0.999764
# NeuralGVAR(static) ep 25/25 loss=0.999746
# [checkpoint] saved: checkpoints/StaticGVAR/RET_h1_h1_tr2021-01-01_te2023-01-01_seed4_lam1.0e-04.pt
#
# ==== RET_h1 ('2021-01-01', '2022-12-31 23:00', '->', '2023-01-01', '2023-12-31 23:00') seed 5 lam 0.0001 ====
# [checkpoint] saved: checkpoints/Last/RET_h1_h1_tr2021-01-01_te2023-01-01_seed5_lam1.0e-04.json
# [checkpoint] saved: checkpoints/VARX_LASSO/RET_h1_h1_tr2021-01-01_te2023-01-01_seed5_lam1.0e-04.pkl
# LSTM ep 1/12 loss=0.000245
# LSTM ep 2/12 loss=0.000152
# LSTM ep 3/12 loss=0.000152
# LSTM ep 4/12 loss=0.000153
# LSTM ep 5/12 loss=0.000154
# LSTM ep 6/12 loss=0.000154
# LSTM ep 7/12 loss=0.000152
# LSTM ep 8/12 loss=0.000152
# LSTM ep 9/12 loss=0.000153
# LSTM ep 10/12 loss=0.000154
# LSTM ep 11/12 loss=0.000153
# LSTM ep 12/12 loss=0.000153
# [checkpoint] saved: checkpoints/LSTM/RET_h1_h1_tr2021-01-01_te2023-01-01_seed5_lam1.0e-04.pt
# NeuralGVAR(gated) ep 1/25 loss=1.279188
# NeuralGVAR(gated) ep 2/25 loss=1.127760
# NeuralGVAR(gated) ep 3/25 loss=1.058164
# NeuralGVAR(gated) ep 4/25 loss=1.026020
# NeuralGVAR(gated) ep 5/25 loss=1.011361
# NeuralGVAR(gated) ep 6/25 loss=1.003969
# NeuralGVAR(gated) ep 7/25 loss=0.999734
# NeuralGVAR(gated) ep 8/25 loss=0.996751
# NeuralGVAR(gated) ep 9/25 loss=0.994460
# NeuralGVAR(gated) ep 10/25 loss=0.992780
# NeuralGVAR(gated) ep 11/25 loss=0.990974
# NeuralGVAR(gated) ep 12/25 loss=0.989706
# NeuralGVAR(gated) ep 13/25 loss=0.988195
# NeuralGVAR(gated) ep 14/25 loss=0.987378
# NeuralGVAR(gated) ep 15/25 loss=0.985769
# NeuralGVAR(gated) ep 16/25 loss=0.984739
# NeuralGVAR(gated) ep 17/25 loss=0.983975
# NeuralGVAR(gated) ep 18/25 loss=0.983205
# NeuralGVAR(gated) ep 19/25 loss=0.982173
# NeuralGVAR(gated) ep 20/25 loss=0.981502
# NeuralGVAR(gated) ep 21/25 loss=0.980479
# NeuralGVAR(gated) ep 22/25 loss=0.980172
# NeuralGVAR(gated) ep 23/25 loss=0.978770
# NeuralGVAR(gated) ep 24/25 loss=0.979051
# NeuralGVAR(gated) ep 25/25 loss=0.979023
# [checkpoint] saved: checkpoints/NeuralGVAR/RET_h1_h1_tr2021-01-01_te2023-01-01_seed5_lam1.0e-04.pt
# NeuralGVAR(static) ep 1/25 loss=1.254110
# NeuralGVAR(static) ep 2/25 loss=1.133911
# NeuralGVAR(static) ep 3/25 loss=1.069466
# NeuralGVAR(static) ep 4/25 loss=1.037524
# NeuralGVAR(static) ep 5/25 loss=1.021869
# NeuralGVAR(static) ep 6/25 loss=1.013503
# NeuralGVAR(static) ep 7/25 loss=1.008514
# NeuralGVAR(static) ep 8/25 loss=1.005329
# NeuralGVAR(static) ep 9/25 loss=1.003248
# NeuralGVAR(static) ep 10/25 loss=1.001896
# NeuralGVAR(static) ep 11/25 loss=1.001034
# NeuralGVAR(static) ep 12/25 loss=1.000499
# NeuralGVAR(static) ep 13/25 loss=1.000174
# NeuralGVAR(static) ep 14/25 loss=0.999981
# NeuralGVAR(static) ep 15/25 loss=0.999867
# NeuralGVAR(static) ep 16/25 loss=0.999799
# NeuralGVAR(static) ep 17/25 loss=0.999757
# NeuralGVAR(static) ep 18/25 loss=0.999729
# NeuralGVAR(static) ep 19/25 loss=0.999710
# NeuralGVAR(static) ep 20/25 loss=0.999695
# NeuralGVAR(static) ep 21/25 loss=0.999685
# NeuralGVAR(static) ep 22/25 loss=0.999677
# NeuralGVAR(static) ep 23/25 loss=0.999671
# NeuralGVAR(static) ep 24/25 loss=0.999668
# NeuralGVAR(static) ep 25/25 loss=0.999667
# [checkpoint] saved: checkpoints/StaticGVAR/RET_h1_h1_tr2021-01-01_te2023-01-01_seed5_lam1.0e-04.pt
#
# ==== RET_h1 ('2021-01-01', '2022-12-31 23:00', '->', '2023-01-01', '2023-12-31 23:00') seed 1 lam 0.0005 ====
# [checkpoint] saved: checkpoints/Last/RET_h1_h1_tr2021-01-01_te2023-01-01_seed1_lam5.0e-04.json
# [checkpoint] saved: checkpoints/VARX_LASSO/RET_h1_h1_tr2021-01-01_te2023-01-01_seed1_lam5.0e-04.pkl
# LSTM ep 1/12 loss=0.000891
# LSTM ep 2/12 loss=0.000152
# LSTM ep 3/12 loss=0.000152
# LSTM ep 4/12 loss=0.000152
# LSTM ep 5/12 loss=0.000152
# LSTM ep 6/12 loss=0.000151
# LSTM ep 7/12 loss=0.000152
# LSTM ep 8/12 loss=0.000152
# LSTM ep 9/12 loss=0.000152
# LSTM ep 10/12 loss=0.000152
# LSTM ep 11/12 loss=0.000152
# LSTM ep 12/12 loss=0.000152
# [checkpoint] saved: checkpoints/LSTM/RET_h1_h1_tr2021-01-01_te2023-01-01_seed1_lam5.0e-04.pt
# NeuralGVAR(gated) ep 1/25 loss=1.321770
# NeuralGVAR(gated) ep 2/25 loss=1.148189
# NeuralGVAR(gated) ep 3/25 loss=1.063616
# NeuralGVAR(gated) ep 4/25 loss=1.026065
# NeuralGVAR(gated) ep 5/25 loss=1.009292
# NeuralGVAR(gated) ep 6/25 loss=1.001513
# NeuralGVAR(gated) ep 7/25 loss=0.997527
# NeuralGVAR(gated) ep 8/25 loss=0.995136
# NeuralGVAR(gated) ep 9/25 loss=0.993601
# NeuralGVAR(gated) ep 10/25 loss=0.992300
# NeuralGVAR(gated) ep 11/25 loss=0.991231
# NeuralGVAR(gated) ep 12/25 loss=0.990360
# NeuralGVAR(gated) ep 13/25 loss=0.989267
# NeuralGVAR(gated) ep 14/25 loss=0.988661
# NeuralGVAR(gated) ep 15/25 loss=0.987899
# NeuralGVAR(gated) ep 16/25 loss=0.987321
# NeuralGVAR(gated) ep 17/25 loss=0.986567
# NeuralGVAR(gated) ep 18/25 loss=0.985799
# NeuralGVAR(gated) ep 19/25 loss=0.985269
# NeuralGVAR(gated) ep 20/25 loss=0.984569
# NeuralGVAR(gated) ep 21/25 loss=0.984167
# NeuralGVAR(gated) ep 22/25 loss=0.983802
# NeuralGVAR(gated) ep 23/25 loss=0.983101
# NeuralGVAR(gated) ep 24/25 loss=0.983061
# NeuralGVAR(gated) ep 25/25 loss=0.982736
# [checkpoint] saved: checkpoints/NeuralGVAR/RET_h1_h1_tr2021-01-01_te2023-01-01_seed1_lam5.0e-04.pt
# NeuralGVAR(static) ep 1/25 loss=1.333132
# NeuralGVAR(static) ep 2/25 loss=1.182892
# NeuralGVAR(static) ep 3/25 loss=1.100199
# NeuralGVAR(static) ep 4/25 loss=1.055400
# NeuralGVAR(static) ep 5/25 loss=1.031549
# NeuralGVAR(static) ep 6/25 loss=1.018737
# NeuralGVAR(static) ep 7/25 loss=1.011719
# NeuralGVAR(static) ep 8/25 loss=1.007749
# NeuralGVAR(static) ep 9/25 loss=1.005377
# NeuralGVAR(static) ep 10/25 loss=1.003858
# NeuralGVAR(static) ep 11/25 loss=1.002819
# NeuralGVAR(static) ep 12/25 loss=1.002077
# NeuralGVAR(static) ep 13/25 loss=1.001532
# NeuralGVAR(static) ep 14/25 loss=1.001125
# NeuralGVAR(static) ep 15/25 loss=1.000817
# NeuralGVAR(static) ep 16/25 loss=1.000580
# NeuralGVAR(static) ep 17/25 loss=1.000398
# NeuralGVAR(static) ep 18/25 loss=1.000257
# NeuralGVAR(static) ep 19/25 loss=1.000146
# NeuralGVAR(static) ep 20/25 loss=1.000061
# NeuralGVAR(static) ep 21/25 loss=0.999994
# NeuralGVAR(static) ep 22/25 loss=0.999944
# NeuralGVAR(static) ep 23/25 loss=0.999906
# NeuralGVAR(static) ep 24/25 loss=0.999879
# NeuralGVAR(static) ep 25/25 loss=0.999860
# [checkpoint] saved: checkpoints/StaticGVAR/RET_h1_h1_tr2021-01-01_te2023-01-01_seed1_lam5.0e-04.pt
#
# ==== RET_h1 ('2021-01-01', '2022-12-31 23:00', '->', '2023-01-01', '2023-12-31 23:00') seed 2 lam 0.0005 ====
# [checkpoint] saved: checkpoints/Last/RET_h1_h1_tr2021-01-01_te2023-01-01_seed2_lam5.0e-04.json
# [checkpoint] saved: checkpoints/VARX_LASSO/RET_h1_h1_tr2021-01-01_te2023-01-01_seed2_lam5.0e-04.pkl
# LSTM ep 1/12 loss=0.000802
# LSTM ep 2/12 loss=0.000152
# LSTM ep 3/12 loss=0.000152
# LSTM ep 4/12 loss=0.000152
# LSTM ep 5/12 loss=0.000152
# LSTM ep 6/12 loss=0.000152
# LSTM ep 7/12 loss=0.000153
# LSTM ep 8/12 loss=0.000152
# LSTM ep 9/12 loss=0.000152
# LSTM ep 10/12 loss=0.000152
# LSTM ep 11/12 loss=0.000152
# LSTM ep 12/12 loss=0.000153
# [checkpoint] saved: checkpoints/LSTM/RET_h1_h1_tr2021-01-01_te2023-01-01_seed2_lam5.0e-04.pt
# NeuralGVAR(gated) ep 1/25 loss=1.304738
# NeuralGVAR(gated) ep 2/25 loss=1.163988
# NeuralGVAR(gated) ep 3/25 loss=1.092770
# NeuralGVAR(gated) ep 4/25 loss=1.055842
# NeuralGVAR(gated) ep 5/25 loss=1.035162
# NeuralGVAR(gated) ep 6/25 loss=1.022456
# NeuralGVAR(gated) ep 7/25 loss=1.014183
# NeuralGVAR(gated) ep 8/25 loss=1.008510
# NeuralGVAR(gated) ep 9/25 loss=1.004326
# NeuralGVAR(gated) ep 10/25 loss=1.001070
# NeuralGVAR(gated) ep 11/25 loss=0.998456
# NeuralGVAR(gated) ep 12/25 loss=0.996218
# NeuralGVAR(gated) ep 13/25 loss=0.994343
# NeuralGVAR(gated) ep 14/25 loss=0.992466
# NeuralGVAR(gated) ep 15/25 loss=0.991116
# NeuralGVAR(gated) ep 16/25 loss=0.989511
# NeuralGVAR(gated) ep 17/25 loss=0.988352
# NeuralGVAR(gated) ep 18/25 loss=0.987189
# NeuralGVAR(gated) ep 19/25 loss=0.986294
# NeuralGVAR(gated) ep 20/25 loss=0.985443
# NeuralGVAR(gated) ep 21/25 loss=0.984421
# NeuralGVAR(gated) ep 22/25 loss=0.983772
# NeuralGVAR(gated) ep 23/25 loss=0.983163
# NeuralGVAR(gated) ep 24/25 loss=0.982220
# NeuralGVAR(gated) ep 25/25 loss=0.981414
# [checkpoint] saved: checkpoints/NeuralGVAR/RET_h1_h1_tr2021-01-01_te2023-01-01_seed2_lam5.0e-04.pt
# NeuralGVAR(static) ep 1/25 loss=1.233376
# NeuralGVAR(static) ep 2/25 loss=1.130723
# NeuralGVAR(static) ep 3/25 loss=1.083160
# NeuralGVAR(static) ep 4/25 loss=1.056061
# NeuralGVAR(static) ep 5/25 loss=1.039216
# NeuralGVAR(static) ep 6/25 loss=1.028121
# NeuralGVAR(static) ep 7/25 loss=1.020511
# NeuralGVAR(static) ep 8/25 loss=1.015143
# NeuralGVAR(static) ep 9/25 loss=1.011283
# NeuralGVAR(static) ep 10/25 loss=1.008471
# NeuralGVAR(static) ep 11/25 loss=1.006403
# NeuralGVAR(static) ep 12/25 loss=1.004870
# NeuralGVAR(static) ep 13/25 loss=1.003725
# NeuralGVAR(static) ep 14/25 loss=1.002863
# NeuralGVAR(static) ep 15/25 loss=1.002210
# NeuralGVAR(static) ep 16/25 loss=1.001710
# NeuralGVAR(static) ep 17/25 loss=1.001326
# NeuralGVAR(static) ep 18/25 loss=1.001027
# NeuralGVAR(static) ep 19/25 loss=1.000794
# NeuralGVAR(static) ep 20/25 loss=1.000610
# NeuralGVAR(static) ep 21/25 loss=1.000464
# NeuralGVAR(static) ep 22/25 loss=1.000349
# NeuralGVAR(static) ep 23/25 loss=1.000256
# NeuralGVAR(static) ep 24/25 loss=1.000183
# NeuralGVAR(static) ep 25/25 loss=1.000124
# [checkpoint] saved: checkpoints/StaticGVAR/RET_h1_h1_tr2021-01-01_te2023-01-01_seed2_lam5.0e-04.pt
#
# ==== RET_h1 ('2021-01-01', '2022-12-31 23:00', '->', '2023-01-01', '2023-12-31 23:00') seed 3 lam 0.0005 ====
# [checkpoint] saved: checkpoints/Last/RET_h1_h1_tr2021-01-01_te2023-01-01_seed3_lam5.0e-04.json
# [checkpoint] saved: checkpoints/VARX_LASSO/RET_h1_h1_tr2021-01-01_te2023-01-01_seed3_lam5.0e-04.pkl
# LSTM ep 1/12 loss=0.000594
# LSTM ep 2/12 loss=0.000153
# LSTM ep 3/12 loss=0.000152
# LSTM ep 4/12 loss=0.000153
# LSTM ep 5/12 loss=0.000152
# LSTM ep 6/12 loss=0.000153
# LSTM ep 7/12 loss=0.000152
# LSTM ep 8/12 loss=0.000153
# LSTM ep 9/12 loss=0.000154
# LSTM ep 10/12 loss=0.000152
# LSTM ep 11/12 loss=0.000153
# LSTM ep 12/12 loss=0.000152
# [checkpoint] saved: checkpoints/LSTM/RET_h1_h1_tr2021-01-01_te2023-01-01_seed3_lam5.0e-04.pt
# NeuralGVAR(gated) ep 1/25 loss=1.160939
# NeuralGVAR(gated) ep 2/25 loss=1.078906
# NeuralGVAR(gated) ep 3/25 loss=1.050224
# NeuralGVAR(gated) ep 4/25 loss=1.036084
# NeuralGVAR(gated) ep 5/25 loss=1.026521
# NeuralGVAR(gated) ep 6/25 loss=1.018966
# NeuralGVAR(gated) ep 7/25 loss=1.012561
# NeuralGVAR(gated) ep 8/25 loss=1.007287
# NeuralGVAR(gated) ep 9/25 loss=1.002928
# NeuralGVAR(gated) ep 10/25 loss=0.999387
# NeuralGVAR(gated) ep 11/25 loss=0.996563
# NeuralGVAR(gated) ep 12/25 loss=0.994316
# NeuralGVAR(gated) ep 13/25 loss=0.992276
# NeuralGVAR(gated) ep 14/25 loss=0.990974
# NeuralGVAR(gated) ep 15/25 loss=0.989517
# NeuralGVAR(gated) ep 16/25 loss=0.988194
# NeuralGVAR(gated) ep 17/25 loss=0.986779
# NeuralGVAR(gated) ep 18/25 loss=0.985776
# NeuralGVAR(gated) ep 19/25 loss=0.984920
# NeuralGVAR(gated) ep 20/25 loss=0.984419
# NeuralGVAR(gated) ep 21/25 loss=0.983695
# NeuralGVAR(gated) ep 22/25 loss=0.983383
# NeuralGVAR(gated) ep 23/25 loss=0.982056
# NeuralGVAR(gated) ep 24/25 loss=0.982077
# NeuralGVAR(gated) ep 25/25 loss=0.980863
# [checkpoint] saved: checkpoints/NeuralGVAR/RET_h1_h1_tr2021-01-01_te2023-01-01_seed3_lam5.0e-04.pt
# NeuralGVAR(static) ep 1/25 loss=1.215758
# NeuralGVAR(static) ep 2/25 loss=1.093529
# NeuralGVAR(static) ep 3/25 loss=1.044012
# NeuralGVAR(static) ep 4/25 loss=1.025366
# NeuralGVAR(static) ep 5/25 loss=1.017338
# NeuralGVAR(static) ep 6/25 loss=1.012633
# NeuralGVAR(static) ep 7/25 loss=1.009271
# NeuralGVAR(static) ep 8/25 loss=1.006733
# NeuralGVAR(static) ep 9/25 loss=1.004811
# NeuralGVAR(static) ep 10/25 loss=1.003371
# NeuralGVAR(static) ep 11/25 loss=1.002308
# NeuralGVAR(static) ep 12/25 loss=1.001537
# NeuralGVAR(static) ep 13/25 loss=1.000987
# NeuralGVAR(static) ep 14/25 loss=1.000601
# NeuralGVAR(static) ep 15/25 loss=1.000336
# NeuralGVAR(static) ep 16/25 loss=1.000156
# NeuralGVAR(static) ep 17/25 loss=1.000036
# NeuralGVAR(static) ep 18/25 loss=0.999958
# NeuralGVAR(static) ep 19/25 loss=0.999909
# NeuralGVAR(static) ep 20/25 loss=0.999879
# NeuralGVAR(static) ep 21/25 loss=0.999861
# NeuralGVAR(static) ep 22/25 loss=0.999853
# NeuralGVAR(static) ep 23/25 loss=0.999851
# NeuralGVAR(static) ep 24/25 loss=0.999853
# NeuralGVAR(static) ep 25/25 loss=0.999858
# [checkpoint] saved: checkpoints/StaticGVAR/RET_h1_h1_tr2021-01-01_te2023-01-01_seed3_lam5.0e-04.pt
#
# ==== RET_h1 ('2021-01-01', '2022-12-31 23:00', '->', '2023-01-01', '2023-12-31 23:00') seed 4 lam 0.0005 ====
# [checkpoint] saved: checkpoints/Last/RET_h1_h1_tr2021-01-01_te2023-01-01_seed4_lam5.0e-04.json
# [checkpoint] saved: checkpoints/VARX_LASSO/RET_h1_h1_tr2021-01-01_te2023-01-01_seed4_lam5.0e-04.pkl
# LSTM ep 1/12 loss=0.001923
# LSTM ep 2/12 loss=0.000152
# LSTM ep 3/12 loss=0.000152
# LSTM ep 4/12 loss=0.000152
# LSTM ep 5/12 loss=0.000152
# LSTM ep 6/12 loss=0.000152
# LSTM ep 7/12 loss=0.000152
# LSTM ep 8/12 loss=0.000152
# LSTM ep 9/12 loss=0.000152
# LSTM ep 10/12 loss=0.000152
# LSTM ep 11/12 loss=0.000152
# LSTM ep 12/12 loss=0.000152
# [checkpoint] saved: checkpoints/LSTM/RET_h1_h1_tr2021-01-01_te2023-01-01_seed4_lam5.0e-04.pt
# NeuralGVAR(gated) ep 1/25 loss=1.310980
# NeuralGVAR(gated) ep 2/25 loss=1.165950
# NeuralGVAR(gated) ep 3/25 loss=1.086200
# NeuralGVAR(gated) ep 4/25 loss=1.045720
# NeuralGVAR(gated) ep 5/25 loss=1.025341
# NeuralGVAR(gated) ep 6/25 loss=1.014094
# NeuralGVAR(gated) ep 7/25 loss=1.006935
# NeuralGVAR(gated) ep 8/25 loss=1.001982
# NeuralGVAR(gated) ep 9/25 loss=0.998225
# NeuralGVAR(gated) ep 10/25 loss=0.995681
# NeuralGVAR(gated) ep 11/25 loss=0.993267
# NeuralGVAR(gated) ep 12/25 loss=0.991490
# NeuralGVAR(gated) ep 13/25 loss=0.990120
# NeuralGVAR(gated) ep 14/25 loss=0.989107
# NeuralGVAR(gated) ep 15/25 loss=0.987878
# NeuralGVAR(gated) ep 16/25 loss=0.987136
# NeuralGVAR(gated) ep 17/25 loss=0.985666
# NeuralGVAR(gated) ep 18/25 loss=0.985153
# NeuralGVAR(gated) ep 19/25 loss=0.984153
# NeuralGVAR(gated) ep 20/25 loss=0.983933
# NeuralGVAR(gated) ep 21/25 loss=0.983304
# NeuralGVAR(gated) ep 22/25 loss=0.982609
# NeuralGVAR(gated) ep 23/25 loss=0.982197
# NeuralGVAR(gated) ep 24/25 loss=0.982067
# NeuralGVAR(gated) ep 25/25 loss=0.981675
# [checkpoint] saved: checkpoints/NeuralGVAR/RET_h1_h1_tr2021-01-01_te2023-01-01_seed4_lam5.0e-04.pt
# NeuralGVAR(static) ep 1/25 loss=1.258678
# NeuralGVAR(static) ep 2/25 loss=1.130789
# NeuralGVAR(static) ep 3/25 loss=1.067042
# NeuralGVAR(static) ep 4/25 loss=1.037610
# NeuralGVAR(static) ep 5/25 loss=1.024310
# NeuralGVAR(static) ep 6/25 loss=1.017434
# NeuralGVAR(static) ep 7/25 loss=1.013024
# NeuralGVAR(static) ep 8/25 loss=1.009773
# NeuralGVAR(static) ep 9/25 loss=1.007283
# NeuralGVAR(static) ep 10/25 loss=1.005384
# NeuralGVAR(static) ep 11/25 loss=1.003956
# NeuralGVAR(static) ep 12/25 loss=1.002893
# NeuralGVAR(static) ep 13/25 loss=1.002107
# NeuralGVAR(static) ep 14/25 loss=1.001526
# NeuralGVAR(static) ep 15/25 loss=1.001096
# NeuralGVAR(static) ep 16/25 loss=1.000777
# NeuralGVAR(static) ep 17/25 loss=1.000539
# NeuralGVAR(static) ep 18/25 loss=1.000360
# NeuralGVAR(static) ep 19/25 loss=1.000225
# NeuralGVAR(static) ep 20/25 loss=1.000124
# NeuralGVAR(static) ep 21/25 loss=1.000048
# NeuralGVAR(static) ep 22/25 loss=0.999992
# NeuralGVAR(static) ep 23/25 loss=0.999952
# NeuralGVAR(static) ep 24/25 loss=0.999924
# NeuralGVAR(static) ep 25/25 loss=0.999905
# [checkpoint] saved: checkpoints/StaticGVAR/RET_h1_h1_tr2021-01-01_te2023-01-01_seed4_lam5.0e-04.pt
#
# ==== RET_h1 ('2021-01-01', '2022-12-31 23:00', '->', '2023-01-01', '2023-12-31 23:00') seed 5 lam 0.0005 ====
# [checkpoint] saved: checkpoints/Last/RET_h1_h1_tr2021-01-01_te2023-01-01_seed5_lam5.0e-04.json
# [checkpoint] saved: checkpoints/VARX_LASSO/RET_h1_h1_tr2021-01-01_te2023-01-01_seed5_lam5.0e-04.pkl
# LSTM ep 1/12 loss=0.000245
# LSTM ep 2/12 loss=0.000152
# LSTM ep 3/12 loss=0.000152
# LSTM ep 4/12 loss=0.000153
# LSTM ep 5/12 loss=0.000154
# LSTM ep 6/12 loss=0.000154
# LSTM ep 7/12 loss=0.000152
# LSTM ep 8/12 loss=0.000152
# LSTM ep 9/12 loss=0.000153
# LSTM ep 10/12 loss=0.000154
# LSTM ep 11/12 loss=0.000153
# LSTM ep 12/12 loss=0.000153
# [checkpoint] saved: checkpoints/LSTM/RET_h1_h1_tr2021-01-01_te2023-01-01_seed5_lam5.0e-04.pt
# NeuralGVAR(gated) ep 1/25 loss=1.279335
# NeuralGVAR(gated) ep 2/25 loss=1.127992
# NeuralGVAR(gated) ep 3/25 loss=1.058469
# NeuralGVAR(gated) ep 4/25 loss=1.026389
# NeuralGVAR(gated) ep 5/25 loss=1.011828
# NeuralGVAR(gated) ep 6/25 loss=1.004503
# NeuralGVAR(gated) ep 7/25 loss=1.000337
# NeuralGVAR(gated) ep 8/25 loss=0.997442
# NeuralGVAR(gated) ep 9/25 loss=0.995412
# NeuralGVAR(gated) ep 10/25 loss=0.993612
# NeuralGVAR(gated) ep 11/25 loss=0.992042
# NeuralGVAR(gated) ep 12/25 loss=0.990634
# NeuralGVAR(gated) ep 13/25 loss=0.989323
# NeuralGVAR(gated) ep 14/25 loss=0.988445
# NeuralGVAR(gated) ep 15/25 loss=0.987086
# NeuralGVAR(gated) ep 16/25 loss=0.986366
# NeuralGVAR(gated) ep 17/25 loss=0.985527
# NeuralGVAR(gated) ep 18/25 loss=0.984436
# NeuralGVAR(gated) ep 19/25 loss=0.983616
# NeuralGVAR(gated) ep 20/25 loss=0.982766
# NeuralGVAR(gated) ep 21/25 loss=0.982036
# NeuralGVAR(gated) ep 22/25 loss=0.981466
# NeuralGVAR(gated) ep 23/25 loss=0.981012
# NeuralGVAR(gated) ep 24/25 loss=0.980519
# NeuralGVAR(gated) ep 25/25 loss=0.980512
# [checkpoint] saved: checkpoints/NeuralGVAR/RET_h1_h1_tr2021-01-01_te2023-01-01_seed5_lam5.0e-04.pt
# NeuralGVAR(static) ep 1/25 loss=1.254196
# NeuralGVAR(static) ep 2/25 loss=1.134028
# NeuralGVAR(static) ep 3/25 loss=1.069592
# NeuralGVAR(static) ep 4/25 loss=1.037658
# NeuralGVAR(static) ep 5/25 loss=1.022011
# NeuralGVAR(static) ep 6/25 loss=1.013650
# NeuralGVAR(static) ep 7/25 loss=1.008666
# NeuralGVAR(static) ep 8/25 loss=1.005484
# NeuralGVAR(static) ep 9/25 loss=1.003405
# NeuralGVAR(static) ep 10/25 loss=1.002054
# NeuralGVAR(static) ep 11/25 loss=1.001193
# NeuralGVAR(static) ep 12/25 loss=1.000657
# NeuralGVAR(static) ep 13/25 loss=1.000333
# NeuralGVAR(static) ep 14/25 loss=1.000140
# NeuralGVAR(static) ep 15/25 loss=1.000027
# NeuralGVAR(static) ep 16/25 loss=0.999959
# NeuralGVAR(static) ep 17/25 loss=0.999916
# NeuralGVAR(static) ep 18/25 loss=0.999889
# NeuralGVAR(static) ep 19/25 loss=0.999869
# NeuralGVAR(static) ep 20/25 loss=0.999855
# NeuralGVAR(static) ep 21/25 loss=0.999844
# NeuralGVAR(static) ep 22/25 loss=0.999836
# NeuralGVAR(static) ep 23/25 loss=0.999831
# NeuralGVAR(static) ep 24/25 loss=0.999828
# NeuralGVAR(static) ep 25/25 loss=0.999827
# [checkpoint] saved: checkpoints/StaticGVAR/RET_h1_h1_tr2021-01-01_te2023-01-01_seed5_lam5.0e-04.pt
#
# ==== RET_h1 ('2021-01-01', '2022-12-31 23:00', '->', '2023-01-01', '2023-12-31 23:00') seed 1 lam 0.001 ====
# [checkpoint] saved: checkpoints/Last/RET_h1_h1_tr2021-01-01_te2023-01-01_seed1_lam1.0e-03.json
# [checkpoint] saved: checkpoints/VARX_LASSO/RET_h1_h1_tr2021-01-01_te2023-01-01_seed1_lam1.0e-03.pkl
# LSTM ep 1/12 loss=0.000891
# LSTM ep 2/12 loss=0.000152
# LSTM ep 3/12 loss=0.000152
# LSTM ep 4/12 loss=0.000152
# LSTM ep 5/12 loss=0.000152
# LSTM ep 6/12 loss=0.000151
# LSTM ep 7/12 loss=0.000152
# LSTM ep 8/12 loss=0.000152
# LSTM ep 9/12 loss=0.000152
# LSTM ep 10/12 loss=0.000152
# LSTM ep 11/12 loss=0.000152
# LSTM ep 12/12 loss=0.000152
# [checkpoint] saved: checkpoints/LSTM/RET_h1_h1_tr2021-01-01_te2023-01-01_seed1_lam1.0e-03.pt
# NeuralGVAR(gated) ep 1/25 loss=1.321925
# NeuralGVAR(gated) ep 2/25 loss=1.148511
# NeuralGVAR(gated) ep 3/25 loss=1.064026
# NeuralGVAR(gated) ep 4/25 loss=1.026503
# NeuralGVAR(gated) ep 5/25 loss=1.009790
# NeuralGVAR(gated) ep 6/25 loss=1.002080
# NeuralGVAR(gated) ep 7/25 loss=0.998137
# NeuralGVAR(gated) ep 8/25 loss=0.995853
# NeuralGVAR(gated) ep 9/25 loss=0.994412
# NeuralGVAR(gated) ep 10/25 loss=0.993145
# NeuralGVAR(gated) ep 11/25 loss=0.992192
# NeuralGVAR(gated) ep 12/25 loss=0.991312
# NeuralGVAR(gated) ep 13/25 loss=0.990591
# NeuralGVAR(gated) ep 14/25 loss=0.989812
# NeuralGVAR(gated) ep 15/25 loss=0.989038
# NeuralGVAR(gated) ep 16/25 loss=0.988571
# NeuralGVAR(gated) ep 17/25 loss=0.987758
# NeuralGVAR(gated) ep 18/25 loss=0.987284
# NeuralGVAR(gated) ep 19/25 loss=0.986580
# NeuralGVAR(gated) ep 20/25 loss=0.986258
# NeuralGVAR(gated) ep 21/25 loss=0.985700
# NeuralGVAR(gated) ep 22/25 loss=0.985262
# NeuralGVAR(gated) ep 23/25 loss=0.984619
# NeuralGVAR(gated) ep 24/25 loss=0.984294
# NeuralGVAR(gated) ep 25/25 loss=0.983888
# [checkpoint] saved: checkpoints/NeuralGVAR/RET_h1_h1_tr2021-01-01_te2023-01-01_seed1_lam1.0e-03.pt
# NeuralGVAR(static) ep 1/25 loss=1.333235
# NeuralGVAR(static) ep 2/25 loss=1.183011
# NeuralGVAR(static) ep 3/25 loss=1.100335
# NeuralGVAR(static) ep 4/25 loss=1.055552
# NeuralGVAR(static) ep 5/25 loss=1.031717
# NeuralGVAR(static) ep 6/25 loss=1.018916
# NeuralGVAR(static) ep 7/25 loss=1.011904
# NeuralGVAR(static) ep 8/25 loss=1.007937
# NeuralGVAR(static) ep 9/25 loss=1.005566
# NeuralGVAR(static) ep 10/25 loss=1.004046
# NeuralGVAR(static) ep 11/25 loss=1.003008
# NeuralGVAR(static) ep 12/25 loss=1.002265
# NeuralGVAR(static) ep 13/25 loss=1.001720
# NeuralGVAR(static) ep 14/25 loss=1.001313
# NeuralGVAR(static) ep 15/25 loss=1.001004
# NeuralGVAR(static) ep 16/25 loss=1.000768
# NeuralGVAR(static) ep 17/25 loss=1.000586
# NeuralGVAR(static) ep 18/25 loss=1.000444
# NeuralGVAR(static) ep 19/25 loss=1.000333
# NeuralGVAR(static) ep 20/25 loss=1.000248
# NeuralGVAR(static) ep 21/25 loss=1.000181
# NeuralGVAR(static) ep 22/25 loss=1.000131
# NeuralGVAR(static) ep 23/25 loss=1.000093
# NeuralGVAR(static) ep 24/25 loss=1.000066
# NeuralGVAR(static) ep 25/25 loss=1.000047
# [checkpoint] saved: checkpoints/StaticGVAR/RET_h1_h1_tr2021-01-01_te2023-01-01_seed1_lam1.0e-03.pt
#
# ==== RET_h1 ('2021-01-01', '2022-12-31 23:00', '->', '2023-01-01', '2023-12-31 23:00') seed 2 lam 0.001 ====
# [checkpoint] saved: checkpoints/Last/RET_h1_h1_tr2021-01-01_te2023-01-01_seed2_lam1.0e-03.json
# [checkpoint] saved: checkpoints/VARX_LASSO/RET_h1_h1_tr2021-01-01_te2023-01-01_seed2_lam1.0e-03.pkl
# LSTM ep 1/12 loss=0.000802
# LSTM ep 2/12 loss=0.000152
# LSTM ep 3/12 loss=0.000152
# LSTM ep 4/12 loss=0.000152
# LSTM ep 5/12 loss=0.000152
# LSTM ep 6/12 loss=0.000152
# LSTM ep 7/12 loss=0.000153
# LSTM ep 8/12 loss=0.000152
# LSTM ep 9/12 loss=0.000152
# LSTM ep 10/12 loss=0.000152
# LSTM ep 11/12 loss=0.000152
# LSTM ep 12/12 loss=0.000153
# [checkpoint] saved: checkpoints/LSTM/RET_h1_h1_tr2021-01-01_te2023-01-01_seed2_lam1.0e-03.pt
# NeuralGVAR(gated) ep 1/25 loss=1.304893
# NeuralGVAR(gated) ep 2/25 loss=1.164232
# NeuralGVAR(gated) ep 3/25 loss=1.093064
# NeuralGVAR(gated) ep 4/25 loss=1.056198
# NeuralGVAR(gated) ep 5/25 loss=1.035608
# NeuralGVAR(gated) ep 6/25 loss=1.023008
# NeuralGVAR(gated) ep 7/25 loss=1.014785
# NeuralGVAR(gated) ep 8/25 loss=1.009136
# NeuralGVAR(gated) ep 9/25 loss=1.005050
# NeuralGVAR(gated) ep 10/25 loss=1.001791
# NeuralGVAR(gated) ep 11/25 loss=0.999302
# NeuralGVAR(gated) ep 12/25 loss=0.997134
# NeuralGVAR(gated) ep 13/25 loss=0.995319
# NeuralGVAR(gated) ep 14/25 loss=0.993795
# NeuralGVAR(gated) ep 15/25 loss=0.992440
# NeuralGVAR(gated) ep 16/25 loss=0.991176
# NeuralGVAR(gated) ep 17/25 loss=0.989987
# NeuralGVAR(gated) ep 18/25 loss=0.988921
# NeuralGVAR(gated) ep 19/25 loss=0.987917
# NeuralGVAR(gated) ep 20/25 loss=0.987200
# NeuralGVAR(gated) ep 21/25 loss=0.986470
# NeuralGVAR(gated) ep 22/25 loss=0.985916
# NeuralGVAR(gated) ep 23/25 loss=0.985136
# NeuralGVAR(gated) ep 24/25 loss=0.984413
# NeuralGVAR(gated) ep 25/25 loss=0.984250
# [checkpoint] saved: checkpoints/NeuralGVAR/RET_h1_h1_tr2021-01-01_te2023-01-01_seed2_lam1.0e-03.pt
# NeuralGVAR(static) ep 1/25 loss=1.233498
# NeuralGVAR(static) ep 2/25 loss=1.130870
# NeuralGVAR(static) ep 3/25 loss=1.083334
# NeuralGVAR(static) ep 4/25 loss=1.056242
# NeuralGVAR(static) ep 5/25 loss=1.039399
# NeuralGVAR(static) ep 6/25 loss=1.028304
# NeuralGVAR(static) ep 7/25 loss=1.020695
# NeuralGVAR(static) ep 8/25 loss=1.015327
# NeuralGVAR(static) ep 9/25 loss=1.011467
# NeuralGVAR(static) ep 10/25 loss=1.008655
# NeuralGVAR(static) ep 11/25 loss=1.006587
# NeuralGVAR(static) ep 12/25 loss=1.005055
# NeuralGVAR(static) ep 13/25 loss=1.003910
# NeuralGVAR(static) ep 14/25 loss=1.003048
# NeuralGVAR(static) ep 15/25 loss=1.002395
# NeuralGVAR(static) ep 16/25 loss=1.001896
# NeuralGVAR(static) ep 17/25 loss=1.001511
# NeuralGVAR(static) ep 18/25 loss=1.001213
# NeuralGVAR(static) ep 19/25 loss=1.000980
# NeuralGVAR(static) ep 20/25 loss=1.000796
# NeuralGVAR(static) ep 21/25 loss=1.000650
# NeuralGVAR(static) ep 22/25 loss=1.000535
# NeuralGVAR(static) ep 23/25 loss=1.000443
# NeuralGVAR(static) ep 24/25 loss=1.000369
# NeuralGVAR(static) ep 25/25 loss=1.000310
# [checkpoint] saved: checkpoints/StaticGVAR/RET_h1_h1_tr2021-01-01_te2023-01-01_seed2_lam1.0e-03.pt
#
# ==== RET_h1 ('2021-01-01', '2022-12-31 23:00', '->', '2023-01-01', '2023-12-31 23:00') seed 3 lam 0.001 ====
# [checkpoint] saved: checkpoints/Last/RET_h1_h1_tr2021-01-01_te2023-01-01_seed3_lam1.0e-03.json
# [checkpoint] saved: checkpoints/VARX_LASSO/RET_h1_h1_tr2021-01-01_te2023-01-01_seed3_lam1.0e-03.pkl
# LSTM ep 1/12 loss=0.000594
# LSTM ep 2/12 loss=0.000153
# LSTM ep 3/12 loss=0.000152
# LSTM ep 4/12 loss=0.000153
# LSTM ep 5/12 loss=0.000152
# LSTM ep 6/12 loss=0.000153
# LSTM ep 7/12 loss=0.000152
# LSTM ep 8/12 loss=0.000153
# LSTM ep 9/12 loss=0.000154
# LSTM ep 10/12 loss=0.000152
# LSTM ep 11/12 loss=0.000153
# LSTM ep 12/12 loss=0.000152
# [checkpoint] saved: checkpoints/LSTM/RET_h1_h1_tr2021-01-01_te2023-01-01_seed3_lam1.0e-03.pt
# NeuralGVAR(gated) ep 1/25 loss=1.161089
# NeuralGVAR(gated) ep 2/25 loss=1.079172
# NeuralGVAR(gated) ep 3/25 loss=1.050576
# NeuralGVAR(gated) ep 4/25 loss=1.036531
# NeuralGVAR(gated) ep 5/25 loss=1.027056
# NeuralGVAR(gated) ep 6/25 loss=1.019602
# NeuralGVAR(gated) ep 7/25 loss=1.013330
# NeuralGVAR(gated) ep 8/25 loss=1.008091
# NeuralGVAR(gated) ep 9/25 loss=1.003876
# NeuralGVAR(gated) ep 10/25 loss=1.000340
# NeuralGVAR(gated) ep 11/25 loss=0.997496
# NeuralGVAR(gated) ep 12/25 loss=0.995564
# NeuralGVAR(gated) ep 13/25 loss=0.993619
# NeuralGVAR(gated) ep 14/25 loss=0.992070
# NeuralGVAR(gated) ep 15/25 loss=0.990533
# NeuralGVAR(gated) ep 16/25 loss=0.989721
# NeuralGVAR(gated) ep 17/25 loss=0.988574
# NeuralGVAR(gated) ep 18/25 loss=0.987656
# NeuralGVAR(gated) ep 19/25 loss=0.986732
# NeuralGVAR(gated) ep 20/25 loss=0.986169
# NeuralGVAR(gated) ep 21/25 loss=0.985671
# NeuralGVAR(gated) ep 22/25 loss=0.984827
# NeuralGVAR(gated) ep 23/25 loss=0.983982
# NeuralGVAR(gated) ep 24/25 loss=0.983805
# NeuralGVAR(gated) ep 25/25 loss=0.983063
# [checkpoint] saved: checkpoints/NeuralGVAR/RET_h1_h1_tr2021-01-01_te2023-01-01_seed3_lam1.0e-03.pt
# NeuralGVAR(static) ep 1/25 loss=1.215851
# NeuralGVAR(static) ep 2/25 loss=1.093644
# NeuralGVAR(static) ep 3/25 loss=1.044164
# NeuralGVAR(static) ep 4/25 loss=1.025538
# NeuralGVAR(static) ep 5/25 loss=1.017519
# NeuralGVAR(static) ep 6/25 loss=1.012818
# NeuralGVAR(static) ep 7/25 loss=1.009457
# NeuralGVAR(static) ep 8/25 loss=1.006919
# NeuralGVAR(static) ep 9/25 loss=1.004997
# NeuralGVAR(static) ep 10/25 loss=1.003557
# NeuralGVAR(static) ep 11/25 loss=1.002494
# NeuralGVAR(static) ep 12/25 loss=1.001723
# NeuralGVAR(static) ep 13/25 loss=1.001173
# NeuralGVAR(static) ep 14/25 loss=1.000787
# NeuralGVAR(static) ep 15/25 loss=1.000522
# NeuralGVAR(static) ep 16/25 loss=1.000342
# NeuralGVAR(static) ep 17/25 loss=1.000223
# NeuralGVAR(static) ep 18/25 loss=1.000145
# NeuralGVAR(static) ep 19/25 loss=1.000095
# NeuralGVAR(static) ep 20/25 loss=1.000065
# NeuralGVAR(static) ep 21/25 loss=1.000048
# NeuralGVAR(static) ep 22/25 loss=1.000039
# NeuralGVAR(static) ep 23/25 loss=1.000037
# NeuralGVAR(static) ep 24/25 loss=1.000039
# NeuralGVAR(static) ep 25/25 loss=1.000045
# [checkpoint] saved: checkpoints/StaticGVAR/RET_h1_h1_tr2021-01-01_te2023-01-01_seed3_lam1.0e-03.pt
#
# ==== RET_h1 ('2021-01-01', '2022-12-31 23:00', '->', '2023-01-01', '2023-12-31 23:00') seed 4 lam 0.001 ====
# [checkpoint] saved: checkpoints/Last/RET_h1_h1_tr2021-01-01_te2023-01-01_seed4_lam1.0e-03.json
# [checkpoint] saved: checkpoints/VARX_LASSO/RET_h1_h1_tr2021-01-01_te2023-01-01_seed4_lam1.0e-03.pkl
# LSTM ep 1/12 loss=0.001923
# LSTM ep 2/12 loss=0.000152
# LSTM ep 3/12 loss=0.000152
# LSTM ep 4/12 loss=0.000152
# LSTM ep 5/12 loss=0.000152
# LSTM ep 6/12 loss=0.000152
# LSTM ep 7/12 loss=0.000152
# LSTM ep 8/12 loss=0.000152
# LSTM ep 9/12 loss=0.000152
# LSTM ep 10/12 loss=0.000152
# LSTM ep 11/12 loss=0.000152
# LSTM ep 12/12 loss=0.000152
# [checkpoint] saved: checkpoints/LSTM/RET_h1_h1_tr2021-01-01_te2023-01-01_seed4_lam1.0e-03.pt
# NeuralGVAR(gated) ep 1/25 loss=1.311112
# NeuralGVAR(gated) ep 2/25 loss=1.166212
# NeuralGVAR(gated) ep 3/25 loss=1.086578
# NeuralGVAR(gated) ep 4/25 loss=1.046200
# NeuralGVAR(gated) ep 5/25 loss=1.025932
# NeuralGVAR(gated) ep 6/25 loss=1.014769
# NeuralGVAR(gated) ep 7/25 loss=1.007747
# NeuralGVAR(gated) ep 8/25 loss=1.002992
# NeuralGVAR(gated) ep 9/25 loss=0.999224
# NeuralGVAR(gated) ep 10/25 loss=0.996451
# NeuralGVAR(gated) ep 11/25 loss=0.994357
# NeuralGVAR(gated) ep 12/25 loss=0.992894
# NeuralGVAR(gated) ep 13/25 loss=0.991078
# NeuralGVAR(gated) ep 14/25 loss=0.990324
# NeuralGVAR(gated) ep 15/25 loss=0.989092
# NeuralGVAR(gated) ep 16/25 loss=0.988278
# NeuralGVAR(gated) ep 17/25 loss=0.987268
# NeuralGVAR(gated) ep 18/25 loss=0.986592
# NeuralGVAR(gated) ep 19/25 loss=0.985759
# NeuralGVAR(gated) ep 20/25 loss=0.985780
# NeuralGVAR(gated) ep 21/25 loss=0.985060
# NeuralGVAR(gated) ep 22/25 loss=0.984567
# NeuralGVAR(gated) ep 23/25 loss=0.984278
# NeuralGVAR(gated) ep 24/25 loss=0.983552
# NeuralGVAR(gated) ep 25/25 loss=0.983382
# [checkpoint] saved: checkpoints/NeuralGVAR/RET_h1_h1_tr2021-01-01_te2023-01-01_seed4_lam1.0e-03.pt
# NeuralGVAR(static) ep 1/25 loss=1.258791
# NeuralGVAR(static) ep 2/25 loss=1.130942
# NeuralGVAR(static) ep 3/25 loss=1.067210
# NeuralGVAR(static) ep 4/25 loss=1.037784
# NeuralGVAR(static) ep 5/25 loss=1.024488
# NeuralGVAR(static) ep 6/25 loss=1.017615
# NeuralGVAR(static) ep 7/25 loss=1.013208
# NeuralGVAR(static) ep 8/25 loss=1.009959
# NeuralGVAR(static) ep 9/25 loss=1.007469
# NeuralGVAR(static) ep 10/25 loss=1.005571
# NeuralGVAR(static) ep 11/25 loss=1.004143
# NeuralGVAR(static) ep 12/25 loss=1.003080
# NeuralGVAR(static) ep 13/25 loss=1.002294
# NeuralGVAR(static) ep 14/25 loss=1.001713
# NeuralGVAR(static) ep 15/25 loss=1.001283
# NeuralGVAR(static) ep 16/25 loss=1.000964
# NeuralGVAR(static) ep 17/25 loss=1.000726
# NeuralGVAR(static) ep 18/25 loss=1.000547
# NeuralGVAR(static) ep 19/25 loss=1.000412
# NeuralGVAR(static) ep 20/25 loss=1.000311
# NeuralGVAR(static) ep 21/25 loss=1.000235
# NeuralGVAR(static) ep 22/25 loss=1.000179
# NeuralGVAR(static) ep 23/25 loss=1.000139
# NeuralGVAR(static) ep 24/25 loss=1.000111
# NeuralGVAR(static) ep 25/25 loss=1.000092
# [checkpoint] saved: checkpoints/StaticGVAR/RET_h1_h1_tr2021-01-01_te2023-01-01_seed4_lam1.0e-03.pt
#
# ==== RET_h1 ('2021-01-01', '2022-12-31 23:00', '->', '2023-01-01', '2023-12-31 23:00') seed 5 lam 0.001 ====
# [checkpoint] saved: checkpoints/Last/RET_h1_h1_tr2021-01-01_te2023-01-01_seed5_lam1.0e-03.json
# [checkpoint] saved: checkpoints/VARX_LASSO/RET_h1_h1_tr2021-01-01_te2023-01-01_seed5_lam1.0e-03.pkl
# LSTM ep 1/12 loss=0.000245
# LSTM ep 2/12 loss=0.000152
# LSTM ep 3/12 loss=0.000152
# LSTM ep 4/12 loss=0.000153
# LSTM ep 5/12 loss=0.000154
# LSTM ep 6/12 loss=0.000154
# LSTM ep 7/12 loss=0.000152
# LSTM ep 8/12 loss=0.000152
# LSTM ep 9/12 loss=0.000153
# LSTM ep 10/12 loss=0.000154
# LSTM ep 11/12 loss=0.000153
# LSTM ep 12/12 loss=0.000153
# [checkpoint] saved: checkpoints/LSTM/RET_h1_h1_tr2021-01-01_te2023-01-01_seed5_lam1.0e-03.pt
# NeuralGVAR(gated) ep 1/25 loss=1.279515
# NeuralGVAR(gated) ep 2/25 loss=1.128269
# NeuralGVAR(gated) ep 3/25 loss=1.058827
# NeuralGVAR(gated) ep 4/25 loss=1.026823
# NeuralGVAR(gated) ep 5/25 loss=1.012379
# NeuralGVAR(gated) ep 6/25 loss=1.005109
# NeuralGVAR(gated) ep 7/25 loss=1.001097
# NeuralGVAR(gated) ep 8/25 loss=0.998306
# NeuralGVAR(gated) ep 9/25 loss=0.996230
# NeuralGVAR(gated) ep 10/25 loss=0.994494
# NeuralGVAR(gated) ep 11/25 loss=0.993172
# NeuralGVAR(gated) ep 12/25 loss=0.991893
# NeuralGVAR(gated) ep 13/25 loss=0.990777
# NeuralGVAR(gated) ep 14/25 loss=0.989529
# NeuralGVAR(gated) ep 15/25 loss=0.988821
# NeuralGVAR(gated) ep 16/25 loss=0.987327
# NeuralGVAR(gated) ep 17/25 loss=0.986857
# NeuralGVAR(gated) ep 18/25 loss=0.985805
# NeuralGVAR(gated) ep 19/25 loss=0.985301
# NeuralGVAR(gated) ep 20/25 loss=0.984302
# NeuralGVAR(gated) ep 21/25 loss=0.983835
# NeuralGVAR(gated) ep 22/25 loss=0.983075
# NeuralGVAR(gated) ep 23/25 loss=0.982657
# NeuralGVAR(gated) ep 24/25 loss=0.982371
# NeuralGVAR(gated) ep 25/25 loss=0.981969
# [checkpoint] saved: checkpoints/NeuralGVAR/RET_h1_h1_tr2021-01-01_te2023-01-01_seed5_lam1.0e-03.pt
# NeuralGVAR(static) ep 1/25 loss=1.254300
# NeuralGVAR(static) ep 2/25 loss=1.134168
# NeuralGVAR(static) ep 3/25 loss=1.069742
# NeuralGVAR(static) ep 4/25 loss=1.037817
# NeuralGVAR(static) ep 5/25 loss=1.022178
# NeuralGVAR(static) ep 6/25 loss=1.013824
# NeuralGVAR(static) ep 7/25 loss=1.008844
# NeuralGVAR(static) ep 8/25 loss=1.005665
# NeuralGVAR(static) ep 9/25 loss=1.003588
# NeuralGVAR(static) ep 10/25 loss=1.002238
# NeuralGVAR(static) ep 11/25 loss=1.001378
# NeuralGVAR(static) ep 12/25 loss=1.000843
# NeuralGVAR(static) ep 13/25 loss=1.000519
# NeuralGVAR(static) ep 14/25 loss=1.000327
# NeuralGVAR(static) ep 15/25 loss=1.000213
# NeuralGVAR(static) ep 16/25 loss=1.000145
# NeuralGVAR(static) ep 17/25 loss=1.000103
# NeuralGVAR(static) ep 18/25 loss=1.000075
# NeuralGVAR(static) ep 19/25 loss=1.000056
# NeuralGVAR(static) ep 20/25 loss=1.000041
# NeuralGVAR(static) ep 21/25 loss=1.000031
# NeuralGVAR(static) ep 22/25 loss=1.000023
# NeuralGVAR(static) ep 23/25 loss=1.000017
# NeuralGVAR(static) ep 24/25 loss=1.000014
# NeuralGVAR(static) ep 25/25 loss=1.000013
# [checkpoint] saved: checkpoints/StaticGVAR/RET_h1_h1_tr2021-01-01_te2023-01-01_seed5_lam1.0e-03.pt
#
# ==== RET_h4 ('2021-01-01', '2022-12-31 23:00', '->', '2023-01-01', '2023-12-31 23:00') seed 1 lam 0.0001 ====
# [checkpoint] saved: checkpoints/Last/RET_h4_h4_tr2021-01-01_te2023-01-01_seed1_lam1.0e-04.json
# [checkpoint] saved: checkpoints/VARX_LASSO/RET_h4_h4_tr2021-01-01_te2023-01-01_seed1_lam1.0e-04.pkl
# LSTM ep 1/12 loss=0.000887
# LSTM ep 2/12 loss=0.000152
# LSTM ep 3/12 loss=0.000151
# LSTM ep 4/12 loss=0.000151
# LSTM ep 5/12 loss=0.000152
# LSTM ep 6/12 loss=0.000152
# LSTM ep 7/12 loss=0.000152
# LSTM ep 8/12 loss=0.000152
# LSTM ep 9/12 loss=0.000152
# LSTM ep 10/12 loss=0.000152
# LSTM ep 11/12 loss=0.000152
# LSTM ep 12/12 loss=0.000152
# [checkpoint] saved: checkpoints/LSTM/RET_h4_h4_tr2021-01-01_te2023-01-01_seed1_lam1.0e-04.pt
# NeuralGVAR(gated) ep 1/25 loss=1.324598
# NeuralGVAR(gated) ep 2/25 loss=1.150938
# NeuralGVAR(gated) ep 3/25 loss=1.066155
# NeuralGVAR(gated) ep 4/25 loss=1.027863
# NeuralGVAR(gated) ep 5/25 loss=1.010837
# NeuralGVAR(gated) ep 6/25 loss=1.003070
# NeuralGVAR(gated) ep 7/25 loss=0.999263
# NeuralGVAR(gated) ep 8/25 loss=0.997201
# NeuralGVAR(gated) ep 9/25 loss=0.995719
# NeuralGVAR(gated) ep 10/25 loss=0.994412
# NeuralGVAR(gated) ep 11/25 loss=0.993426
# NeuralGVAR(gated) ep 12/25 loss=0.992561
# NeuralGVAR(gated) ep 13/25 loss=0.991311
# NeuralGVAR(gated) ep 14/25 loss=0.990534
# NeuralGVAR(gated) ep 15/25 loss=0.989410
# NeuralGVAR(gated) ep 16/25 loss=0.988642
# NeuralGVAR(gated) ep 17/25 loss=0.987927
# NeuralGVAR(gated) ep 18/25 loss=0.987413
# NeuralGVAR(gated) ep 19/25 loss=0.986557
# NeuralGVAR(gated) ep 20/25 loss=0.985636
# NeuralGVAR(gated) ep 21/25 loss=0.985187
# NeuralGVAR(gated) ep 22/25 loss=0.985263
# NeuralGVAR(gated) ep 23/25 loss=0.984054
# NeuralGVAR(gated) ep 24/25 loss=0.983078
# NeuralGVAR(gated) ep 25/25 loss=0.982559
# [checkpoint] saved: checkpoints/NeuralGVAR/RET_h4_h4_tr2021-01-01_te2023-01-01_seed1_lam1.0e-04.pt
# NeuralGVAR(static) ep 1/25 loss=1.332056
# NeuralGVAR(static) ep 2/25 loss=1.179694
# NeuralGVAR(static) ep 3/25 loss=1.097627
# NeuralGVAR(static) ep 4/25 loss=1.053826
# NeuralGVAR(static) ep 5/25 loss=1.030784
# NeuralGVAR(static) ep 6/25 loss=1.018517
# NeuralGVAR(static) ep 7/25 loss=1.011827
# NeuralGVAR(static) ep 8/25 loss=1.008049
# NeuralGVAR(static) ep 9/25 loss=1.005793
# NeuralGVAR(static) ep 10/25 loss=1.004347
# NeuralGVAR(static) ep 11/25 loss=1.003358
# NeuralGVAR(static) ep 12/25 loss=1.002652
# NeuralGVAR(static) ep 13/25 loss=1.002134
# NeuralGVAR(static) ep 14/25 loss=1.001746
# NeuralGVAR(static) ep 15/25 loss=1.001451
# NeuralGVAR(static) ep 16/25 loss=1.001224
# NeuralGVAR(static) ep 17/25 loss=1.001047
# NeuralGVAR(static) ep 18/25 loss=1.000908
# NeuralGVAR(static) ep 19/25 loss=1.000799
# NeuralGVAR(static) ep 20/25 loss=1.000712
# NeuralGVAR(static) ep 21/25 loss=1.000645
# NeuralGVAR(static) ep 22/25 loss=1.000592
# NeuralGVAR(static) ep 23/25 loss=1.000552
# NeuralGVAR(static) ep 24/25 loss=1.000523
# NeuralGVAR(static) ep 25/25 loss=1.000502
# [checkpoint] saved: checkpoints/StaticGVAR/RET_h4_h4_tr2021-01-01_te2023-01-01_seed1_lam1.0e-04.pt
#
# ==== RET_h4 ('2021-01-01', '2022-12-31 23:00', '->', '2023-01-01', '2023-12-31 23:00') seed 2 lam 0.0001 ====
# [checkpoint] saved: checkpoints/Last/RET_h4_h4_tr2021-01-01_te2023-01-01_seed2_lam1.0e-04.json
# [checkpoint] saved: checkpoints/VARX_LASSO/RET_h4_h4_tr2021-01-01_te2023-01-01_seed2_lam1.0e-04.pkl
# ...
# NeuralGVAR(static) ep 4/25 loss=0.706210
# NeuralGVAR(static) ep 5/25 loss=0.695071
# NeuralGVAR(static) ep 6/25 loss=0.687470
# NeuralGVAR(static) ep 7/25 loss=0.682113
# NeuralGVAR(static) ep 8/25 loss=0.678344
# NeuralGVAR(static) ep 9/25 loss=0.675715
# NeuralGVAR(static) ep 10/25 loss=0.673886
# NeuralGVAR(static) ep 11/25 loss=0.672607
# NeuralGVAR(static) ep 12/25 loss=0.671699
# NeuralGVAR(static) ep 13/25 loss=0.671038
# NeuralGVAR(static) ep 14/25 loss=0.670543
# NeuralGVAR(static) ep 15/25 loss=0.670158
# NeuralGVAR(static) ep 16/25 loss=0.669848
# NeuralGVAR(static) ep 17/25 loss=0.669591
# NeuralGVAR(static) ep 18/25 loss=0.669370
# NeuralGVAR(static) ep 19/25 loss=0.669176
# NeuralGVAR(static) ep 20/25 loss=0.669003
# NeuralGVAR(static) ep 21/25 loss=0.668847
# NeuralGVAR(static) ep 22/25 loss=0.668704
# NeuralGVAR(static) ep 23/25 loss=0.668573
# NeuralGVAR(static) ep 24/25 loss=0.668453
# NeuralGVAR(static) ep 25/25 loss=0.668342
# [checkpoint] saved: checkpoints/StaticGVAR/VOL_h24_h24_tr2022-01-01_te2025-01-01_seed5_lam5.0e-04.pt
#
# ==== VOL_h24 ('2022-01-01', '2024-12-31 23:00', '->', '2025-01-01', '2025-12-25 23:00') seed 1 lam 0.001 ====
# [checkpoint] saved: checkpoints/Last/VOL_h24_h24_tr2022-01-01_te2025-01-01_seed1_lam1.0e-03.json
# [checkpoint] saved: checkpoints/VARX_LASSO/VOL_h24_h24_tr2022-01-01_te2025-01-01_seed1_lam1.0e-03.pkl
# LSTM ep 1/12 loss=0.000577
# LSTM ep 2/12 loss=0.000018
# LSTM ep 3/12 loss=0.000018
# LSTM ep 4/12 loss=0.000017
# LSTM ep 5/12 loss=0.000016
# LSTM ep 6/12 loss=0.000015
# LSTM ep 7/12 loss=0.000015
# LSTM ep 8/12 loss=0.000014
# LSTM ep 9/12 loss=0.000014
# LSTM ep 10/12 loss=0.000014
# LSTM ep 11/12 loss=0.000014
# LSTM ep 12/12 loss=0.000014
# [checkpoint] saved: checkpoints/LSTM/VOL_h24_h24_tr2022-01-01_te2025-01-01_seed1_lam1.0e-03.pt
# NeuralGVAR(gated) ep 1/25 loss=1.072452
# NeuralGVAR(gated) ep 2/25 loss=0.785198
# NeuralGVAR(gated) ep 3/25 loss=0.716990
# NeuralGVAR(gated) ep 4/25 loss=0.690678
# NeuralGVAR(gated) ep 5/25 loss=0.678616
# NeuralGVAR(gated) ep 6/25 loss=0.667927
# NeuralGVAR(gated) ep 7/25 loss=0.663231
# NeuralGVAR(gated) ep 8/25 loss=0.654339
# NeuralGVAR(gated) ep 9/25 loss=0.651876
# NeuralGVAR(gated) ep 10/25 loss=0.653222
# NeuralGVAR(gated) ep 11/25 loss=0.642613
# NeuralGVAR(gated) ep 12/25 loss=0.640590
# NeuralGVAR(gated) ep 13/25 loss=0.630398
# NeuralGVAR(gated) ep 14/25 loss=0.646801
# NeuralGVAR(gated) ep 15/25 loss=0.638750
# NeuralGVAR(gated) ep 16/25 loss=0.635215
# NeuralGVAR(gated) ep 17/25 loss=0.622590
# NeuralGVAR(gated) ep 18/25 loss=0.621906
# NeuralGVAR(gated) ep 19/25 loss=0.620302
# NeuralGVAR(gated) ep 20/25 loss=0.617169
# NeuralGVAR(gated) ep 21/25 loss=0.616746
# NeuralGVAR(gated) ep 22/25 loss=0.615005
# NeuralGVAR(gated) ep 23/25 loss=0.617535
# NeuralGVAR(gated) ep 24/25 loss=0.616600
# NeuralGVAR(gated) ep 25/25 loss=0.615674
# [checkpoint] saved: checkpoints/NeuralGVAR/VOL_h24_h24_tr2022-01-01_te2025-01-01_seed1_lam1.0e-03.pt
# NeuralGVAR(static) ep 1/25 loss=1.024406
# NeuralGVAR(static) ep 2/25 loss=0.808222
# NeuralGVAR(static) ep 3/25 loss=0.743588
# NeuralGVAR(static) ep 4/25 loss=0.717215
# NeuralGVAR(static) ep 5/25 loss=0.704060
# NeuralGVAR(static) ep 6/25 loss=0.695980
# NeuralGVAR(static) ep 7/25 loss=0.690200
# NeuralGVAR(static) ep 8/25 loss=0.685761
# NeuralGVAR(static) ep 9/25 loss=0.682269
# NeuralGVAR(static) ep 10/25 loss=0.679506
# NeuralGVAR(static) ep 11/25 loss=0.677320
# NeuralGVAR(static) ep 12/25 loss=0.675593
# NeuralGVAR(static) ep 13/25 loss=0.674232
# NeuralGVAR(static) ep 14/25 loss=0.673159
# NeuralGVAR(static) ep 15/25 loss=0.672314
# NeuralGVAR(static) ep 16/25 loss=0.671648
# NeuralGVAR(static) ep 17/25 loss=0.671120
# NeuralGVAR(static) ep 18/25 loss=0.670701
# NeuralGVAR(static) ep 19/25 loss=0.670365
# NeuralGVAR(static) ep 20/25 loss=0.670093
# NeuralGVAR(static) ep 21/25 loss=0.669871
# NeuralGVAR(static) ep 22/25 loss=0.669687
# NeuralGVAR(static) ep 23/25 loss=0.669533
# NeuralGVAR(static) ep 24/25 loss=0.669403
# NeuralGVAR(static) ep 25/25 loss=0.669290
# [checkpoint] saved: checkpoints/StaticGVAR/VOL_h24_h24_tr2022-01-01_te2025-01-01_seed1_lam1.0e-03.pt
#
# ==== VOL_h24 ('2022-01-01', '2024-12-31 23:00', '->', '2025-01-01', '2025-12-25 23:00') seed 2 lam 0.001 ====
# [checkpoint] saved: checkpoints/Last/VOL_h24_h24_tr2022-01-01_te2025-01-01_seed2_lam1.0e-03.json
# [checkpoint] saved: checkpoints/VARX_LASSO/VOL_h24_h24_tr2022-01-01_te2025-01-01_seed2_lam1.0e-03.pkl
# LSTM ep 1/12 loss=0.000411
# LSTM ep 2/12 loss=0.000018
# LSTM ep 3/12 loss=0.000017
# LSTM ep 4/12 loss=0.000016
# LSTM ep 5/12 loss=0.000015
# LSTM ep 6/12 loss=0.000014
# LSTM ep 7/12 loss=0.000014
# LSTM ep 8/12 loss=0.000014
# LSTM ep 9/12 loss=0.000014
# LSTM ep 10/12 loss=0.000014
# LSTM ep 11/12 loss=0.000014
# LSTM ep 12/12 loss=0.000014
# [checkpoint] saved: checkpoints/LSTM/VOL_h24_h24_tr2022-01-01_te2025-01-01_seed2_lam1.0e-03.pt
# NeuralGVAR(gated) ep 1/25 loss=1.093317
# NeuralGVAR(gated) ep 2/25 loss=0.812194
# NeuralGVAR(gated) ep 3/25 loss=0.734348
# NeuralGVAR(gated) ep 4/25 loss=0.701855
# NeuralGVAR(gated) ep 5/25 loss=0.684427
# NeuralGVAR(gated) ep 6/25 loss=0.677407
# NeuralGVAR(gated) ep 7/25 loss=0.663261
# NeuralGVAR(gated) ep 8/25 loss=0.665007
# NeuralGVAR(gated) ep 9/25 loss=0.650378
# NeuralGVAR(gated) ep 10/25 loss=0.654049
# NeuralGVAR(gated) ep 11/25 loss=0.640166
# NeuralGVAR(gated) ep 12/25 loss=0.649668
# NeuralGVAR(gated) ep 13/25 loss=0.639176
# NeuralGVAR(gated) ep 14/25 loss=0.642321
# NeuralGVAR(gated) ep 15/25 loss=0.628573
# NeuralGVAR(gated) ep 16/25 loss=0.628668
# NeuralGVAR(gated) ep 17/25 loss=0.625130
# NeuralGVAR(gated) ep 18/25 loss=0.625193
# NeuralGVAR(gated) ep 19/25 loss=0.622586
# NeuralGVAR(gated) ep 20/25 loss=0.624495
# NeuralGVAR(gated) ep 21/25 loss=0.619875
# NeuralGVAR(gated) ep 22/25 loss=0.621375
# NeuralGVAR(gated) ep 23/25 loss=0.619211
# NeuralGVAR(gated) ep 24/25 loss=0.617052
# NeuralGVAR(gated) ep 25/25 loss=0.617060
# [checkpoint] saved: checkpoints/NeuralGVAR/VOL_h24_h24_tr2022-01-01_te2025-01-01_seed2_lam1.0e-03.pt
# NeuralGVAR(static) ep 1/25 loss=1.057590
# NeuralGVAR(static) ep 2/25 loss=0.834452
# NeuralGVAR(static) ep 3/25 loss=0.771619
# NeuralGVAR(static) ep 4/25 loss=0.740700
# NeuralGVAR(static) ep 5/25 loss=0.722435
# NeuralGVAR(static) ep 6/25 loss=0.710204
# NeuralGVAR(static) ep 7/25 loss=0.701253
# NeuralGVAR(static) ep 8/25 loss=0.694378
# NeuralGVAR(static) ep 9/25 loss=0.688990
# NeuralGVAR(static) ep 10/25 loss=0.684747
# NeuralGVAR(static) ep 11/25 loss=0.681411
# NeuralGVAR(static) ep 12/25 loss=0.678801
# NeuralGVAR(static) ep 13/25 loss=0.676768
# NeuralGVAR(static) ep 14/25 loss=0.675191
# NeuralGVAR(static) ep 15/25 loss=0.673972
# NeuralGVAR(static) ep 16/25 loss=0.673029
# NeuralGVAR(static) ep 17/25 loss=0.672299
# NeuralGVAR(static) ep 18/25 loss=0.671731
# NeuralGVAR(static) ep 19/25 loss=0.671284
# NeuralGVAR(static) ep 20/25 loss=0.670929
# NeuralGVAR(static) ep 21/25 loss=0.670641
# NeuralGVAR(static) ep 22/25 loss=0.670405
# NeuralGVAR(static) ep 23/25 loss=0.670206
# NeuralGVAR(static) ep 24/25 loss=0.670037
# NeuralGVAR(static) ep 25/25 loss=0.669889
# [checkpoint] saved: checkpoints/StaticGVAR/VOL_h24_h24_tr2022-01-01_te2025-01-01_seed2_lam1.0e-03.pt
#
# ==== VOL_h24 ('2022-01-01', '2024-12-31 23:00', '->', '2025-01-01', '2025-12-25 23:00') seed 3 lam 0.001 ====
# [checkpoint] saved: checkpoints/Last/VOL_h24_h24_tr2022-01-01_te2025-01-01_seed3_lam1.0e-03.json
# [checkpoint] saved: checkpoints/VARX_LASSO/VOL_h24_h24_tr2022-01-01_te2025-01-01_seed3_lam1.0e-03.pkl
# LSTM ep 1/12 loss=0.000293
# LSTM ep 2/12 loss=0.000018
# LSTM ep 3/12 loss=0.000016
# LSTM ep 4/12 loss=0.000015
# LSTM ep 5/12 loss=0.000015
# LSTM ep 6/12 loss=0.000014
# LSTM ep 7/12 loss=0.000014
# LSTM ep 8/12 loss=0.000014
# LSTM ep 9/12 loss=0.000014
# LSTM ep 10/12 loss=0.000014
# LSTM ep 11/12 loss=0.000014
# LSTM ep 12/12 loss=0.000014
# [checkpoint] saved: checkpoints/LSTM/VOL_h24_h24_tr2022-01-01_te2025-01-01_seed3_lam1.0e-03.pt
# NeuralGVAR(gated) ep 1/25 loss=1.026397
# NeuralGVAR(gated) ep 2/25 loss=0.828319
# NeuralGVAR(gated) ep 3/25 loss=0.765986
# NeuralGVAR(gated) ep 4/25 loss=0.727698
# NeuralGVAR(gated) ep 5/25 loss=0.703592
# NeuralGVAR(gated) ep 6/25 loss=0.692747
# NeuralGVAR(gated) ep 7/25 loss=0.674903
# NeuralGVAR(gated) ep 8/25 loss=0.668971
# NeuralGVAR(gated) ep 9/25 loss=0.656307
# NeuralGVAR(gated) ep 10/25 loss=0.652739
# NeuralGVAR(gated) ep 11/25 loss=0.647274
# NeuralGVAR(gated) ep 12/25 loss=0.645588
# NeuralGVAR(gated) ep 13/25 loss=0.636189
# NeuralGVAR(gated) ep 14/25 loss=0.633557
# NeuralGVAR(gated) ep 15/25 loss=0.628891
# NeuralGVAR(gated) ep 16/25 loss=0.634182
# NeuralGVAR(gated) ep 17/25 loss=0.641078
# NeuralGVAR(gated) ep 18/25 loss=0.633555
# NeuralGVAR(gated) ep 19/25 loss=0.630175
# NeuralGVAR(gated) ep 20/25 loss=0.627753
# NeuralGVAR(gated) ep 21/25 loss=0.633222
# NeuralGVAR(gated) ep 22/25 loss=0.618685
# NeuralGVAR(gated) ep 23/25 loss=0.619264
# NeuralGVAR(gated) ep 24/25 loss=0.617791
# NeuralGVAR(gated) ep 25/25 loss=0.617197
# [checkpoint] saved: checkpoints/NeuralGVAR/VOL_h24_h24_tr2022-01-01_te2025-01-01_seed3_lam1.0e-03.pt
# NeuralGVAR(static) ep 1/25 loss=0.986300
# NeuralGVAR(static) ep 2/25 loss=0.794196
# NeuralGVAR(static) ep 3/25 loss=0.745337
# NeuralGVAR(static) ep 4/25 loss=0.723303
# NeuralGVAR(static) ep 5/25 loss=0.709846
# NeuralGVAR(static) ep 6/25 loss=0.700442
# NeuralGVAR(static) ep 7/25 loss=0.693492
# NeuralGVAR(static) ep 8/25 loss=0.688229
# NeuralGVAR(static) ep 9/25 loss=0.684199
# NeuralGVAR(static) ep 10/25 loss=0.681100
# NeuralGVAR(static) ep 11/25 loss=0.678710
# NeuralGVAR(static) ep 12/25 loss=0.676858
# NeuralGVAR(static) ep 13/25 loss=0.675416
# NeuralGVAR(static) ep 14/25 loss=0.674285
# NeuralGVAR(static) ep 15/25 loss=0.673391
# NeuralGVAR(static) ep 16/25 loss=0.672678
# NeuralGVAR(static) ep 17/25 loss=0.672103
# NeuralGVAR(static) ep 18/25 loss=0.671636
# NeuralGVAR(static) ep 19/25 loss=0.671251
# NeuralGVAR(static) ep 20/25 loss=0.670931
# NeuralGVAR(static) ep 21/25 loss=0.670661
# NeuralGVAR(static) ep 22/25 loss=0.670431
# NeuralGVAR(static) ep 23/25 loss=0.670233
# NeuralGVAR(static) ep 24/25 loss=0.670060
# NeuralGVAR(static) ep 25/25 loss=0.669908
# [checkpoint] saved: checkpoints/StaticGVAR/VOL_h24_h24_tr2022-01-01_te2025-01-01_seed3_lam1.0e-03.pt
#
# ==== VOL_h24 ('2022-01-01', '2024-12-31 23:00', '->', '2025-01-01', '2025-12-25 23:00') seed 4 lam 0.001 ====
# [checkpoint] saved: checkpoints/Last/VOL_h24_h24_tr2022-01-01_te2025-01-01_seed4_lam1.0e-03.json
# [checkpoint] saved: checkpoints/VARX_LASSO/VOL_h24_h24_tr2022-01-01_te2025-01-01_seed4_lam1.0e-03.pkl
# LSTM ep 1/12 loss=0.001227
# LSTM ep 2/12 loss=0.000018
# LSTM ep 3/12 loss=0.000017
# LSTM ep 4/12 loss=0.000017
# LSTM ep 5/12 loss=0.000016
# LSTM ep 6/12 loss=0.000015
# LSTM ep 7/12 loss=0.000015
# LSTM ep 8/12 loss=0.000014
# LSTM ep 9/12 loss=0.000014
# LSTM ep 10/12 loss=0.000014
# LSTM ep 11/12 loss=0.000014
# LSTM ep 12/12 loss=0.000014
# [checkpoint] saved: checkpoints/LSTM/VOL_h24_h24_tr2022-01-01_te2025-01-01_seed4_lam1.0e-03.pt
# NeuralGVAR(gated) ep 1/25 loss=1.011530
# NeuralGVAR(gated) ep 2/25 loss=0.767652
# NeuralGVAR(gated) ep 3/25 loss=0.713315
# NeuralGVAR(gated) ep 4/25 loss=0.691209
# NeuralGVAR(gated) ep 5/25 loss=0.680307
# NeuralGVAR(gated) ep 6/25 loss=0.669745
# NeuralGVAR(gated) ep 7/25 loss=0.657639
# NeuralGVAR(gated) ep 8/25 loss=0.664633
# NeuralGVAR(gated) ep 9/25 loss=0.651092
# NeuralGVAR(gated) ep 10/25 loss=0.650274
# NeuralGVAR(gated) ep 11/25 loss=0.645459
# NeuralGVAR(gated) ep 12/25 loss=0.646178
# NeuralGVAR(gated) ep 13/25 loss=0.652997
# NeuralGVAR(gated) ep 14/25 loss=0.640807
# NeuralGVAR(gated) ep 15/25 loss=0.641950
# NeuralGVAR(gated) ep 16/25 loss=0.636167
# NeuralGVAR(gated) ep 17/25 loss=0.639348
# NeuralGVAR(gated) ep 18/25 loss=0.630912
# NeuralGVAR(gated) ep 19/25 loss=0.625813
# NeuralGVAR(gated) ep 20/25 loss=0.622935
# NeuralGVAR(gated) ep 21/25 loss=0.619965
# NeuralGVAR(gated) ep 22/25 loss=0.620139
# NeuralGVAR(gated) ep 23/25 loss=0.616852
# NeuralGVAR(gated) ep 24/25 loss=0.618110
# NeuralGVAR(gated) ep 25/25 loss=0.614165
# [checkpoint] saved: checkpoints/NeuralGVAR/VOL_h24_h24_tr2022-01-01_te2025-01-01_seed4_lam1.0e-03.pt
# NeuralGVAR(static) ep 1/25 loss=1.002556
# NeuralGVAR(static) ep 2/25 loss=0.795281
# NeuralGVAR(static) ep 3/25 loss=0.743990
# NeuralGVAR(static) ep 4/25 loss=0.722295
# NeuralGVAR(static) ep 5/25 loss=0.709809
# NeuralGVAR(static) ep 6/25 loss=0.701080
# NeuralGVAR(static) ep 7/25 loss=0.694468
# NeuralGVAR(static) ep 8/25 loss=0.689335
# NeuralGVAR(static) ep 9/25 loss=0.685311
# NeuralGVAR(static) ep 10/25 loss=0.682138
# NeuralGVAR(static) ep 11/25 loss=0.679624
# NeuralGVAR(static) ep 12/25 loss=0.677622
# NeuralGVAR(static) ep 13/25 loss=0.676022
# NeuralGVAR(static) ep 14/25 loss=0.674738
# NeuralGVAR(static) ep 15/25 loss=0.673705
# NeuralGVAR(static) ep 16/25 loss=0.672869
# NeuralGVAR(static) ep 17/25 loss=0.672191
# NeuralGVAR(static) ep 18/25 loss=0.671639
# NeuralGVAR(static) ep 19/25 loss=0.671185
# NeuralGVAR(static) ep 20/25 loss=0.670812
# NeuralGVAR(static) ep 21/25 loss=0.670502
# NeuralGVAR(static) ep 22/25 loss=0.670242
# NeuralGVAR(static) ep 23/25 loss=0.670023
# NeuralGVAR(static) ep 24/25 loss=0.669836
# NeuralGVAR(static) ep 25/25 loss=0.669676
# [checkpoint] saved: checkpoints/StaticGVAR/VOL_h24_h24_tr2022-01-01_te2025-01-01_seed4_lam1.0e-03.pt
#
# ==== VOL_h24 ('2022-01-01', '2024-12-31 23:00', '->', '2025-01-01', '2025-12-25 23:00') seed 5 lam 0.001 ====
# [checkpoint] saved: checkpoints/Last/VOL_h24_h24_tr2022-01-01_te2025-01-01_seed5_lam1.0e-03.json
# [checkpoint] saved: checkpoints/VARX_LASSO/VOL_h24_h24_tr2022-01-01_te2025-01-01_seed5_lam1.0e-03.pkl
# LSTM ep 1/12 loss=0.000102
# LSTM ep 2/12 loss=0.000018
# LSTM ep 3/12 loss=0.000016
# LSTM ep 4/12 loss=0.000015
# LSTM ep 5/12 loss=0.000014
# LSTM ep 6/12 loss=0.000014
# LSTM ep 7/12 loss=0.000014
# LSTM ep 8/12 loss=0.000014
# LSTM ep 9/12 loss=0.000014
# LSTM ep 10/12 loss=0.000014
# LSTM ep 11/12 loss=0.000014
# LSTM ep 12/12 loss=0.000014
# [checkpoint] saved: checkpoints/LSTM/VOL_h24_h24_tr2022-01-01_te2025-01-01_seed5_lam1.0e-03.pt
# NeuralGVAR(gated) ep 1/25 loss=1.056248
# NeuralGVAR(gated) ep 2/25 loss=0.773171
# NeuralGVAR(gated) ep 3/25 loss=0.708020
# NeuralGVAR(gated) ep 4/25 loss=0.691527
# NeuralGVAR(gated) ep 5/25 loss=0.675426
# NeuralGVAR(gated) ep 6/25 loss=0.672739
# NeuralGVAR(gated) ep 7/25 loss=0.661657
# NeuralGVAR(gated) ep 8/25 loss=0.662268
# NeuralGVAR(gated) ep 9/25 loss=0.653593
# NeuralGVAR(gated) ep 10/25 loss=0.651562
# NeuralGVAR(gated) ep 11/25 loss=0.646052
# NeuralGVAR(gated) ep 12/25 loss=0.655236
# NeuralGVAR(gated) ep 13/25 loss=0.643259
# NeuralGVAR(gated) ep 14/25 loss=0.643289
# NeuralGVAR(gated) ep 15/25 loss=0.636477
# NeuralGVAR(gated) ep 16/25 loss=0.637550
# NeuralGVAR(gated) ep 17/25 loss=0.631999
# NeuralGVAR(gated) ep 18/25 loss=0.638329
# NeuralGVAR(gated) ep 19/25 loss=0.624845
# NeuralGVAR(gated) ep 20/25 loss=0.646618
# NeuralGVAR(gated) ep 21/25 loss=0.630082
# NeuralGVAR(gated) ep 22/25 loss=0.628592
# NeuralGVAR(gated) ep 23/25 loss=0.618587
# NeuralGVAR(gated) ep 24/25 loss=0.618440
# NeuralGVAR(gated) ep 25/25 loss=0.615888
# [checkpoint] saved: checkpoints/NeuralGVAR/VOL_h24_h24_tr2022-01-01_te2025-01-01_seed5_lam1.0e-03.pt
# NeuralGVAR(static) ep 1/25 loss=0.928512
# NeuralGVAR(static) ep 2/25 loss=0.765225
# NeuralGVAR(static) ep 3/25 loss=0.725214
# NeuralGVAR(static) ep 4/25 loss=0.706773
# NeuralGVAR(static) ep 5/25 loss=0.695678
# NeuralGVAR(static) ep 6/25 loss=0.688118
# NeuralGVAR(static) ep 7/25 loss=0.682799
# NeuralGVAR(static) ep 8/25 loss=0.679068
# NeuralGVAR(static) ep 9/25 loss=0.676476
# NeuralGVAR(static) ep 10/25 loss=0.674681
# NeuralGVAR(static) ep 11/25 loss=0.673432
# NeuralGVAR(static) ep 12/25 loss=0.672550
# NeuralGVAR(static) ep 13/25 loss=0.671914
# NeuralGVAR(static) ep 14/25 loss=0.671440
# NeuralGVAR(static) ep 15/25 loss=0.671076
# NeuralGVAR(static) ep 16/25 loss=0.670785
# NeuralGVAR(static) ep 17/25 loss=0.670544
# NeuralGVAR(static) ep 18/25 loss=0.670340
# NeuralGVAR(static) ep 19/25 loss=0.670161
# NeuralGVAR(static) ep 20/25 loss=0.670003
# NeuralGVAR(static) ep 21/25 loss=0.669860
# NeuralGVAR(static) ep 22/25 loss=0.669730
# NeuralGVAR(static) ep 23/25 loss=0.669612
# NeuralGVAR(static) ep 24/25 loss=0.669502
# NeuralGVAR(static) ep 25/25 loss=0.669402
# [checkpoint] saved: checkpoints/StaticGVAR/VOL_h24_h24_tr2022-01-01_te2025-01-01_seed5_lam1.0e-03.pt
# Runs completed: 360

# %% [markdown]
# ## 8) Aggregate into per-horizon tables (metrics, hypotheses, test-window conditioning, event conditioning)

# %%
# ---- metrics_summary.csv (aggregated test metrics across runs) ----
import numpy as np
import pandas as pd
import os
from pathlib import Path

# This notebook stores metrics nested per run:
#   results[i]["metrics"] == {model_name: {"MSE":..., "MAE":..., ...}, ...}
if "results" not in globals() or results is None or len(results) == 0:
    raise RuntimeError("No `results` found. Run the experiment loop first to populate `results`.")

rows = []
for r in results:
    task = r.get("task", None)
    h = int(r.get("h", -1))
    seed = r.get("seed", None)
    lam_sparse = r.get("lam_sparse", None)

    win = f'{r.get("train_start","")}-{r.get("train_end","")}->' \
          f'{r.get("test_start","")}-{r.get("test_end","")}'

    metrics = r.get("metrics", {}) or {}
    for model, md in metrics.items():
        if md is None:
            continue
        rows.append({
            "task": task,
            "h": h,
            "model": str(model),
            "MSE": float(md.get("MSE", np.nan)),
            "MAE": float(md.get("MAE", np.nan)),
            "SignHitRate": float(md.get("SignHitRate", np.nan)) if ("SignHitRate" in md) else np.nan,
            "seed": seed,
            "lam_sparse": lam_sparse,
            "window": win,
        })

met_df = pd.DataFrame(rows)
met_df = met_df.dropna(subset=["task", "h", "model", "MSE", "MAE"]).copy()

# Aggregate across runs (mean ± std, and n)
metrics_summary = (
    met_df.groupby(["task", "h", "model"], as_index=False)
          .agg(
              MSE_mean=("MSE", "mean"),
              MSE_std=("MSE", "std"),
              MAE_mean=("MAE", "mean"),
              MAE_std=("MAE", "std"),
              SignHit_mean=("SignHitRate", "mean"),
              SignHit_std=("SignHitRate", "std"),
              n=("MSE", "count"),
          )
)

# std is NaN when n==1; replace with 0 for plotting
for col in ["MSE_std", "MAE_std", "SignHit_std"]:
    if col in metrics_summary.columns:
        metrics_summary[col] = metrics_summary[col].fillna(0.0)

# Stable ordering in tables/plots
model_order = {"VARX-LASSO": 0, "StaticGVAR": 1, "NeuralGVAR": 2, "LSTM": 3, "Last": 4}
metrics_summary["model_rank"] = metrics_summary["model"].map(model_order).fillna(99).astype(int)
metrics_summary = (
    metrics_summary.sort_values(["task", "h", "model_rank"])
                   .drop(columns=["model_rank"])
                   .reset_index(drop=True)
)

# Output locations
PAPER_ASSETS = globals().get("PAPER_ASSETS", "paper_assets")
Path(PAPER_ASSETS).mkdir(parents=True, exist_ok=True)

out1 = os.path.join(PAPER_ASSETS, "metrics_summary.csv")

metrics_summary.to_csv(out1, index=False)

# Sanity check: do we have all expected models for every (task, h)?
expected = set(model_order.keys())
missing = []
for (t, hh), g in metrics_summary.groupby(["task", "h"]):
    present = set(g["model"].astype(str))
    miss = sorted(expected - present)
    if miss:
        missing.append((t, int(hh), miss))

print(f"Saved metrics_summary to: {out1}")

if missing:
    print("WARNING: missing models for some (task, h):")
    for t, hh, miss in missing[:30]:
        print(f"  - {t} h={hh}: missing {miss}")
else:
    print("All expected models present for each (task, h).")

metrics_summary.head(15)
# Out:
# Saved metrics_summary to: paper_assets/metrics_summary.csv
# All expected models present for each (task, h).
#        task   h       model  MSE_mean   MSE_std  MAE_mean   MAE_std  \
# 0    RET_h1   1  VARX-LASSO  0.000055  0.000004  0.004635  0.000384
# 1    RET_h1   1  StaticGVAR  0.000055  0.000004  0.004642  0.000383
# 2    RET_h1   1  NeuralGVAR  0.000055  0.000004  0.004654  0.000382
# 3    RET_h1   1        LSTM  0.000056  0.000004  0.004732  0.000418
# 4    RET_h1   1        Last  0.000111  0.000009  0.006848  0.000534
# 5   RET_h12  12  VARX-LASSO  0.000055  0.000004  0.004637  0.000384
# 6   RET_h12  12  StaticGVAR  0.000055  0.000004  0.004647  0.000384
# 7   RET_h12  12  NeuralGVAR  0.000055  0.000004  0.004655  0.000384
# 8   RET_h12  12        LSTM  0.000056  0.000004  0.004734  0.000365
# 9   RET_h12  12        Last  0.000112  0.000007  0.006879  0.000521
# 10  RET_h24  24  VARX-LASSO  0.000055  0.000004  0.004640  0.000379
# 11  RET_h24  24  StaticGVAR  0.000055  0.000004  0.004645  0.000377
# 12  RET_h24  24  NeuralGVAR  0.000055  0.000004  0.004656  0.000376
# 13  RET_h24  24        LSTM  0.000056  0.000004  0.004709  0.000377
# 14  RET_h24  24        Last  0.000109  0.000007  0.006814  0.000526
#
#     SignHit_mean  SignHit_std   n
# 0       0.507089     0.004829  45
# 1       0.501226     0.004698  45
# 2       0.501542     0.002444  45
# 3       0.499789     0.006422  45
# 4       0.481683     0.002747  45
# 5       0.502132     0.003462  45
# 6       0.497047     0.004586  45
# 7       0.498808     0.004004  45
# 8       0.500570     0.004604  45
# 9       0.495704     0.003007  45
# 10      0.488774     0.012594  45
# 11      0.497085     0.004183  45
# 12      0.498086     0.003129  45
# 13      0.499913     0.004450  45
# 14      0.506564     0.008309  45

# %%
# ---- Sanity checks for metrics_summary.csv ----
expected_models = ["Last", "VARX-LASSO", "StaticGVAR", "NeuralGVAR", "LSTM"]

missing = []
for (task, h), g in metrics_summary.groupby(["task", "h"]):
    present = set(g["model"])
    miss = [m for m in expected_models if m not in present]
    if miss:
        missing.append((task, h, miss))

if missing:
    print("WARNING: Missing models for some (task,h):")
    for task, h, miss in missing:
        print(f"  - {task}, h={h}: missing {miss}")
else:
    print("OK: All expected models present for each (task,h) group.")

print("\nRun counts (n) by (task,h):")
display(metrics_summary.groupby(["task", "h"])["n"].describe())

print("\nExample scale checks (MSE_mean):")
display(metrics_summary.pivot_table(index=["task","h"], columns="model", values="MSE_mean", aggfunc="first").head(10))
# Out:
# OK: All expected models present for each (task,h) group.
#
# Run counts (n) by (task,h):
#             count  mean  std   min   25%   50%   75%   max
# task    h
# RET_h1  1     5.0  45.0  0.0  45.0  45.0  45.0  45.0  45.0
# RET_h12 12    5.0  45.0  0.0  45.0  45.0  45.0  45.0  45.0
# RET_h24 24    5.0  45.0  0.0  45.0  45.0  45.0  45.0  45.0
# RET_h4  4     5.0  45.0  0.0  45.0  45.0  45.0  45.0  45.0
# VOL_h1  1     5.0  45.0  0.0  45.0  45.0  45.0  45.0  45.0
# VOL_h12 12    5.0  45.0  0.0  45.0  45.0  45.0  45.0  45.0
# VOL_h24 24    5.0  45.0  0.0  45.0  45.0  45.0  45.0  45.0
# VOL_h4  4     5.0  45.0  0.0  45.0  45.0  45.0  45.0  45.0
# Example scale checks (MSE_mean):
# model           LSTM          Last    NeuralGVAR    StaticGVAR    VARX-LASSO
# task    h
# RET_h1  1   0.000056  1.107119e-04  5.527532e-05  5.502608e-05  5.494302e-05
# RET_h12 12  0.000056  1.117733e-04  5.515893e-05  5.508430e-05  5.492275e-05
# RET_h24 24  0.000056  1.090340e-04  5.522256e-05  5.503406e-05  5.497226e-05
# RET_h4  4   0.000056  1.097901e-04  5.518056e-05  5.499949e-05  5.490185e-05
# VOL_h1  1   0.000004  6.955136e-07  7.738413e-07  7.680758e-07  7.266366e-07
# VOL_h12 12  0.000008  1.195155e-05  5.320602e-06  5.128999e-06  5.216912e-06
# VOL_h24 24  0.000012  1.222126e-05  1.019587e-05  9.809325e-06  9.980701e-06
# VOL_h4  4   0.000005  1.933092e-06  1.940437e-06  1.901008e-06  1.890049e-06

# %%
def run_event_conditioning_for_run(
    r,
    model_key="NeuralGVAR",
    edge_source="BTCUSDT",
    edge_target="ETHUSDT",
    event_mode="jump",
):
    ex = r["extras"][model_key]
    idx = pd.to_datetime(ex["test_index"])
    if getattr(idx, "tz", None) is None:
        idx = idx.tz_localize("UTC")
    idx = pd.DatetimeIndex(idx)

    # edge series from A_test
    e = edge_timeseries(ex["A_test"], ASSET_IDX[edge_source], ASSET_IDX[edge_target])
    e_series = pd.Series(e, index=idx)

    # matching series (volatility of edge_source)
    ms = panel[(edge_source, VOL_COL)].reindex(idx).astype(float)

    if event_mode == "jump":
        s = panel[(edge_source, RET_COL)].reindex(idx).astype(float)
        events, thr = define_events(s, q=EVENT_Q, mode="abs")
    else:
        s = panel[(edge_source, VOL_COL)].reindex(idx).astype(float)
        events, thr = define_events(s, q=EVENT_Q, mode="high")

    d_real = event_pre_post_delta(e_series, events, pre=EVENT_PRE_H, post=EVENT_POST_H)
    controls = matched_control_events(events, ms, exclude=events, n_bins=MATCH_BINS, seed=r["seed"])
    d_ctrl  = event_pre_post_delta(e_series, controls, pre=EVENT_PRE_H, post=EVENT_POST_H)
    d_shift = event_pre_post_delta(e_series, placebo_shift(events, hours=-6), pre=EVENT_PRE_H, post=EVENT_POST_H)
    d_rand  = event_pre_post_delta(e_series, random_events(idx, n=len(events), seed=r["seed"]), pre=EVENT_PRE_H, post=EVENT_POST_H)

    return {
        "model": model_key,
        "task": r["task"],
        "h": r["h"],
        "edge": f"{edge_source}→{edge_target}",
        "event_mode": event_mode,
        "events_n": int(len(events)),
        "threshold": thr,
        "real_mean": float(np.mean(d_real)) if len(d_real) else np.nan,
        "ctrl_mean": float(np.mean(d_ctrl)) if len(d_ctrl) else np.nan,
        "shift_mean": float(np.mean(d_shift)) if len(d_shift) else np.nan,
        "rand_mean": float(np.mean(d_rand)) if len(d_rand) else np.nan,
    }


ev_rows = []
for r in results:
    for model_key in ["StaticGVAR", "NeuralGVAR"]:
        if r["task"].startswith("RET"):
            ev_rows.append(run_event_conditioning_for_run(r, model_key, "BTCUSDT", "ETHUSDT", "jump"))
        if r["task"].startswith("VOL"):
            ev_rows.append(run_event_conditioning_for_run(r, model_key, "BTCUSDT", "ETHUSDT", "vol"))
            ev_rows.append(run_event_conditioning_for_run(r, model_key, "BTCUSDT", "SOLUSDT", "vol"))

ev_df = pd.DataFrame(ev_rows)

event_conditioning_summary = (
    ev_df.groupby(["model","task","h","edge","event_mode"])
         .agg(
             events_n_mean=("events_n","mean"),
             real_mean=("real_mean","mean"),
             real_std =("real_mean","std"),
             ctrl_mean=("ctrl_mean","mean"),
             ctrl_std =("ctrl_mean","std"),
             shift_mean=("shift_mean","mean"),
             shift_std =("shift_mean","std"),
             rand_mean=("rand_mean","mean"),
             rand_std =("rand_mean","std"),
             n=("real_mean","count"),
         )
         .reset_index()
         .sort_values(["task","h","edge","event_mode","model"])
)

event_conditioning_summary
# Out:
#          model     task   h             edge event_mode  events_n_mean  \
# 0   NeuralGVAR   RET_h1   1  BTCUSDT→ETHUSDT       jump      87.666667
# 12  StaticGVAR   RET_h1   1  BTCUSDT→ETHUSDT       jump      87.666667
# 1   NeuralGVAR  RET_h12  12  BTCUSDT→ETHUSDT       jump      87.666667
# 13  StaticGVAR  RET_h12  12  BTCUSDT→ETHUSDT       jump      87.666667
# 2   NeuralGVAR  RET_h24  24  BTCUSDT→ETHUSDT       jump      87.333333
# 14  StaticGVAR  RET_h24  24  BTCUSDT→ETHUSDT       jump      87.333333
# 3   NeuralGVAR   RET_h4   4  BTCUSDT→ETHUSDT       jump      87.666667
# 15  StaticGVAR   RET_h4   4  BTCUSDT→ETHUSDT       jump      87.666667
# 4   NeuralGVAR   VOL_h1   1  BTCUSDT→ETHUSDT        vol      87.666667
# 16  StaticGVAR   VOL_h1   1  BTCUSDT→ETHUSDT        vol      87.666667
# 5   NeuralGVAR   VOL_h1   1  BTCUSDT→SOLUSDT        vol      87.666667
# 17  StaticGVAR   VOL_h1   1  BTCUSDT→SOLUSDT        vol      87.666667
# 6   NeuralGVAR  VOL_h12  12  BTCUSDT→ETHUSDT        vol      87.666667
# 18  StaticGVAR  VOL_h12  12  BTCUSDT→ETHUSDT        vol      87.666667
# 7   NeuralGVAR  VOL_h12  12  BTCUSDT→SOLUSDT        vol      87.666667
# 19  StaticGVAR  VOL_h12  12  BTCUSDT→SOLUSDT        vol      87.666667
# 8   NeuralGVAR  VOL_h24  24  BTCUSDT→ETHUSDT        vol      87.333333
# 20  StaticGVAR  VOL_h24  24  BTCUSDT→ETHUSDT        vol      87.333333
# 9   NeuralGVAR  VOL_h24  24  BTCUSDT→SOLUSDT        vol      87.333333
# 21  StaticGVAR  VOL_h24  24  BTCUSDT→SOLUSDT        vol      87.333333
# 10  NeuralGVAR   VOL_h4   4  BTCUSDT→ETHUSDT        vol      87.666667
# 22  StaticGVAR   VOL_h4   4  BTCUSDT→ETHUSDT        vol      87.666667
# 11  NeuralGVAR   VOL_h4   4  BTCUSDT→SOLUSDT        vol      87.666667
# 23  StaticGVAR   VOL_h4   4  BTCUSDT→SOLUSDT        vol      87.666667
#
#     real_mean  real_std     ctrl_mean      ctrl_std  shift_mean  shift_std  \
# 0    0.000738  0.003020 -1.436426e-03  1.986818e-03    0.001453   0.002830
# 12   0.000000  0.000000 -1.881460e-12  1.262122e-11    0.000000   0.000000
# 1   -0.000348  0.003409  4.666585e-05  2.451936e-03    0.000789   0.003516
# 13   0.000000  0.000000 -1.763869e-13  8.738799e-13    0.000000   0.000000
# 2   -0.000121  0.001885 -6.102835e-04  2.379232e-03    0.001486   0.002186
# 14   0.000000  0.000000  4.703650e-13  3.155304e-12    0.000000   0.000000
# 3    0.000141  0.001545 -4.916068e-04  2.904238e-03    0.003138   0.003216
# 15   0.000000  0.000000  0.000000e+00  4.512696e-12    0.000000   0.000000
# 4   -0.000217  0.000969  6.506202e-05  8.575459e-04   -0.000325   0.001743
# 16   0.000000  0.000000  0.000000e+00  0.000000e+00    0.000000   0.000000
# 5   -0.000270  0.000704 -5.246433e-05  3.005475e-04   -0.000347   0.000905
# 17   0.000000  0.000000  0.000000e+00  0.000000e+00    0.000000   0.000000
# 6   -0.002814  0.003669  1.757750e-03  2.858304e-03   -0.004031   0.005838
# 18   0.000000  0.000000  0.000000e+00  0.000000e+00    0.000000   0.000000
# 7   -0.001900  0.003132 -8.999428e-04  2.543205e-03   -0.001400   0.003876
# 19   0.000000  0.000000  0.000000e+00  0.000000e+00    0.000000   0.000000
# 8   -0.002174  0.003167 -1.196990e-03  2.436635e-03   -0.000526   0.005632
# 20   0.000000  0.000000  0.000000e+00  0.000000e+00    0.000000   0.000000
# 9   -0.002901  0.004830 -1.616869e-03  4.740357e-03   -0.001051   0.003714
# 21   0.000000  0.000000  0.000000e+00  0.000000e+00    0.000000   0.000000
# 10  -0.001018  0.001431  6.538658e-04  1.750543e-03   -0.001265   0.002936
# 22   0.000000  0.000000  0.000000e+00  0.000000e+00    0.000000   0.000000
# 11  -0.000813  0.000987 -1.221299e-04  9.069122e-04   -0.001002   0.001451
# 23   0.000000  0.000000  0.000000e+00  0.000000e+00    0.000000   0.000000
#
#        rand_mean      rand_std   n
# 0  -3.922443e-04  1.722071e-03  45
# 12  0.000000e+00  0.000000e+00  45
# 1   4.829800e-04  2.840973e-03  45
# 13  0.000000e+00  9.129133e-12  45
# 2   5.867133e-04  1.050947e-03  45
# 14  0.000000e+00  0.000000e+00  45
# 3   9.112988e-04  2.385576e-03  45
# 15 -4.757714e-13  2.230989e-12  45
# 4  -1.049810e-04  6.187444e-04  45
# 16  0.000000e+00  0.000000e+00  45
# 5  -2.392000e-05  3.238746e-04  45
# 17  0.000000e+00  0.000000e+00  45
# 6   1.495872e-04  2.333005e-03  45
# 18  1.903086e-12  1.276629e-11  45
# 7  -4.084797e-04  1.390482e-03  45
# 19  1.903086e-12  1.276629e-11  45
# 8  -3.739477e-04  1.919319e-03  45
# 20  0.000000e+00  0.000000e+00  45
# 9  -1.072788e-03  2.769665e-03  45
# 21  0.000000e+00  0.000000e+00  45
# 10  4.912621e-05  1.288237e-03  45
# 22 -9.515429e-13  6.383144e-12  45
# 11 -3.230671e-05  7.010531e-04  45
# 23  0.000000e+00  0.000000e+00  45

# %%
# 8.3 H1 + H4a: test-window only conditioning and Wc diagonal, per horizon
h1_rows=[]
h4a_rows=[]

for r in results:
    task = r["task"]; h = r["h"]
    te_start = pd.Timestamp(r["test_start"], tz="UTC")
    te_end   = pd.Timestamp(r["test_end"], tz="UTC")
    test_panel = panel.loc[te_start:te_end].copy()
    ex = r["extras"]["NeuralGVAR"]

    if task.startswith("RET"):
        cond = conditioning_delta_on_test(test_panel, h, concept_feat=DIV_COL, y_feat=RET_COL, q=0.99, mode="abs")
        for a in SYMBOLS:
            h1_rows.append({
                "task": task, "h": h,
                "hyp": "H1 divergence→returns (−)",
                "asset": a,
                "Wc_diag": diag_concept_weight(ex, DIV_COL, a),
                "cond_delta": cond[a],
            })

    if task.startswith("VOL"):
        cond = conditioning_delta_on_test(test_panel, h, concept_feat=FUND_COL, y_feat=VOL_COL, q=0.99, mode="high")
        for a in SYMBOLS:
            h4a_rows.append({
                "task": task, "h": h,
                "hyp": "H4a funding→volatility (+)",
                "asset": a,
                "Wc_diag": diag_concept_weight(ex, FUND_COL, a),
                "cond_delta": cond[a],
            })

h1_df = pd.DataFrame(h1_rows)
h4a_df = pd.DataFrame(h4a_rows)

h1_summary = (h1_df.groupby(["task","h","hyp","asset"])
              .agg(Wc_mean=("Wc_diag","mean"), Wc_std=("Wc_diag","std"),
                   cond_delta_mean=("cond_delta","mean"), cond_delta_std=("cond_delta","std"),
                   n=("Wc_diag","count"))
              .reset_index().sort_values(["task","asset"]))
h4a_summary = (h4a_df.groupby(["task","h","hyp","asset"])
               .agg(Wc_mean=("Wc_diag","mean"), Wc_std=("Wc_diag","std"),
                    cond_delta_mean=("cond_delta","mean"), cond_delta_std=("cond_delta","std"),
                    n=("Wc_diag","count"))
               .reset_index().sort_values(["task","asset"]))

h1_summary, h4a_summary
# Out:
# (       task   h                        hyp    asset   Wc_mean    Wc_std  \
#  0    RET_h1   1  H1 divergence→returns (−)  BTCUSDT  0.012037  0.006983
#  1    RET_h1   1  H1 divergence→returns (−)  ETHUSDT  0.009365  0.006849
#  2    RET_h1   1  H1 divergence→returns (−)  SOLUSDT -0.005072  0.010439
#  3   RET_h12  12  H1 divergence→returns (−)  BTCUSDT  0.005904  0.003198
#  4   RET_h12  12  H1 divergence→returns (−)  ETHUSDT  0.007817  0.002457
#  5   RET_h12  12  H1 divergence→returns (−)  SOLUSDT -0.005777  0.002090
#  6   RET_h24  24  H1 divergence→returns (−)  BTCUSDT  0.001647  0.005777
#  7   RET_h24  24  H1 divergence→returns (−)  ETHUSDT -0.004433  0.004614
#  8   RET_h24  24  H1 divergence→returns (−)  SOLUSDT  0.000430  0.005702
#  9    RET_h4   4  H1 divergence→returns (−)  BTCUSDT  0.012150  0.007299
#  10   RET_h4   4  H1 divergence→returns (−)  ETHUSDT -0.004508  0.006711
#  11   RET_h4   4  H1 divergence→returns (−)  SOLUSDT -0.000528  0.012608
#
#      cond_delta_mean  cond_delta_std   n
#  0          0.000355        0.000292  45
#  1          0.000533        0.000570  45
#  2         -0.000084        0.000518  45
#  3         -0.000270        0.000255  45
#  4          0.000920        0.000279  45
#  5         -0.000165        0.000746  45
#  6         -0.000095        0.000290  45
#  7          0.000188        0.000550  45
#  8          0.000069        0.000308  45
#  9          0.000213        0.000362  45
#  10         0.000325        0.000719  45
#  11         0.000524        0.000655  45  ,
#         task   h                         hyp    asset   Wc_mean    Wc_std  \
#  0    VOL_h1   1  H4a funding→volatility (+)  BTCUSDT -0.009651  0.015672
#  1    VOL_h1   1  H4a funding→volatility (+)  ETHUSDT -0.026154  0.035286
#  2    VOL_h1   1  H4a funding→volatility (+)  SOLUSDT -0.000123  0.010591
#  3   VOL_h12  12  H4a funding→volatility (+)  BTCUSDT  0.003283  0.035680
#  4   VOL_h12  12  H4a funding→volatility (+)  ETHUSDT -0.038770  0.047528
#  5   VOL_h12  12  H4a funding→volatility (+)  SOLUSDT -0.004023  0.036504
#  6   VOL_h24  24  H4a funding→volatility (+)  BTCUSDT  0.022649  0.050213
#  7   VOL_h24  24  H4a funding→volatility (+)  ETHUSDT -0.041499  0.065089
#  8   VOL_h24  24  H4a funding→volatility (+)  SOLUSDT -0.014345  0.060251
#  9    VOL_h4   4  H4a funding→volatility (+)  BTCUSDT -0.006523  0.022971
#  10   VOL_h4   4  H4a funding→volatility (+)  ETHUSDT -0.026591  0.036884
#  11   VOL_h4   4  H4a funding→volatility (+)  SOLUSDT -0.002104  0.019570
#
#      cond_delta_mean  cond_delta_std   n
#  0          0.001065        0.001597  45
#  1          0.001496        0.001080  45
#  2          0.003578        0.002558  45
#  3          0.001234        0.001723  45
#  4          0.001492        0.001078  45
#  5          0.004664        0.003282  45
#  6          0.000935        0.001278  45
#  7          0.001285        0.001149  45
#  8          0.004705        0.003415  45
#  9          0.001149        0.001688  45
#  10         0.001487        0.001047  45
#  11         0.003889        0.002687  45  )

# %% [markdown]
# ## 9) Export CSV + LaTeX + PNG figures

# %%
# 9) Export paper_assets (tables + figures)
# Writes plots/tables into ./paper_assets and prints where they were saved.

from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

assets_dir = Path("paper_assets")
assets_dir.mkdir(parents=True, exist_ok=True)

def _task_prefix(task: str) -> str:
    t = str(task).upper()
    if "RET" in t:
        return "RET"
    if "VOL" in t:
        return "VOL"
    return t.replace(" ", "_")

def _ensure_task_and_h(df: pd.DataFrame) -> pd.DataFrame:
    """Ensure columns: task (RET/VOL) and h (int). Accepts legacy task strings like RET_h1."""
    df = df.copy()
    if "task" not in df.columns:
        raise KeyError("metrics_summary must contain a 'task' column (or be created in this notebook).")
    if "h" not in df.columns:
        # legacy format: task like 'RET_h1'
        h = df["task"].astype(str).str.extract(r"h(\d+)")[0]
        if h.isna().any():
            raise KeyError("Could not parse horizon `h` from task names. Expected strings like 'RET_h1'.")
        df["h"] = h.astype(int)
        df["task"] = df["task"].astype(str).str.replace(r"_h\d+$", "", regex=True)
    else:
        df["h"] = df["h"].astype(int)
    return df

def _safe_to_latex(df: pd.DataFrame, path: Path) -> None:
    df.to_latex(path, index=False, float_format="%.6g")

# -------------------- Save summary CSV + LaTeX --------------------
if "metrics_summary" in globals():
    metrics_summary.to_csv(assets_dir / "metrics_summary.csv", index=False)
    _safe_to_latex(metrics_summary, assets_dir / "metrics_summary.tex")

for name in ["edge_hypothesis_summary", "h1_summary", "h4a_summary", "event_conditioning_summary"]:
    if name in globals():
        globals()[name].to_csv(assets_dir / f"{name}.csv", index=False)
        _safe_to_latex(globals()[name], assets_dir / f"{name}.tex")

# -------------------- Plots: baselines from metrics_summary --------------------
def plot_metric_bars(metrics_df: pd.DataFrame, task: str, h: int, metric: str) -> Path | None:
    df = metrics_df[(metrics_df["task"] == task) & (metrics_df["h"] == h)].copy()
    if df.empty:
        return None

    order = ["Last", "VARX-LASSO", "StaticGVAR", "NeuralGVAR", "LSTM"]
    if "model" in df.columns:
        df["model"] = pd.Categorical(df["model"], categories=order, ordered=True)
        df = df.sort_values("model")

    mean_col = f"{metric}_mean"
    std_col  = f"{metric}_std"
    if mean_col not in df.columns:
        return None

    means = df[mean_col].to_numpy()
    stds  = df[std_col].to_numpy() if std_col in df.columns else np.zeros_like(means)

    plt.figure(figsize=(7.0, 3.2))
    plt.bar(np.arange(len(df)), means, yerr=stds, capsize=3)
    plt.xticks(np.arange(len(df)), df["model"].astype(str).tolist(), rotation=20)
    plt.ylabel(f"Test {metric}")
    plt.title(f"{_task_prefix(task)} — horizon h={h}")
    plt.tight_layout()

    out = assets_dir / f"{metric.lower()}_{_task_prefix(task)}_h{h}.png"
    plt.savefig(out, dpi=200)
    plt.close()
    return out

# If the user didn't run the aggregation cell, fall back to reading an existing CSV
if "metrics_summary" in globals():
    _metrics_df = metrics_summary
else:
    _csv = Path("metrics_summary.csv")
    _metrics_df = pd.read_csv(_csv) if _csv.exists() else None

saved = []

if _metrics_df is not None and not _metrics_df.empty:
    _metrics_df = _ensure_task_and_h(_metrics_df)

    for task in sorted(_metrics_df["task"].unique()):
        for h in sorted(_metrics_df[_metrics_df["task"].eq(task)]["h"].unique()):
            h = int(h)
            for metric in ["MSE", "MAE"]:
                out = plot_metric_bars(_metrics_df, task, h, metric)
                if out is not None:
                    saved.append(out)

            # VOL often has QLIKE (if present)
            if "QLIKE_mean" in _metrics_df.columns:
                out = plot_metric_bars(_metrics_df, task, h, "QLIKE")
                if out is not None:
                    saved.append(out)

# -------------------- Plots: concept outcome conditioning (H1/H4a) --------------------
def plot_conditioning(summary_df: pd.DataFrame, task: str, h: int,
                      value_col: str, ylabel: str, title: str, fname: Path) -> Path | None:
    df = summary_df[(summary_df["task"] == task) & (summary_df["h"] == h)].copy()
    if df.empty or value_col not in df.columns:
        return None

    label_col = None
    for cand in ["target", "symbol", "var", "series", "node"]:
        if cand in df.columns:
            label_col = cand
            break
    if label_col is None:
        label_col = df.columns[0]

    labels = df[label_col].astype(str).tolist()
    vals = df[value_col].to_numpy()

    plt.figure(figsize=(6.2, 3.2))
    plt.bar(np.arange(len(vals)), vals)
    plt.axhline(0.0, linestyle="--")
    plt.xticks(np.arange(len(vals)), labels, rotation=0)
    plt.ylabel(ylabel)
    plt.title(f"{title} — {_task_prefix(task)} — h={h}")
    plt.tight_layout()
    plt.savefig(fname, dpi=200)
    plt.close()
    return fname

if "h1_summary" in globals():
    h1_summary = _ensure_task_and_h(h1_summary)
    for task in sorted(h1_summary["task"].unique()):
        for h in sorted(h1_summary[h1_summary["task"].eq(task)]["h"].unique()):
            h = int(h)
            out = assets_dir / f"h1_cond_{_task_prefix(task)}_h{h}.png"
            p = plot_conditioning(
                h1_summary, task, h,
                value_col="cond_delta_mean",
                ylabel=r"$\mathbb{E}[r_{t+h}\mid |div|\ extreme]-\mathbb{E}[r_{t+h}]$",
                title="H1 conditioning",
                fname=out
            )
            if p is not None:
                saved.append(p)

if "h4a_summary" in globals():
    h4a_summary = _ensure_task_and_h(h4a_summary)
    for task in sorted(h4a_summary["task"].unique()):
        for h in sorted(h4a_summary[h4a_summary["task"].eq(task)]["h"].unique()):
            h = int(h)
            out = assets_dir / f"h4a_cond_{_task_prefix(task)}_h{h}.png"
            p = plot_conditioning(
                h4a_summary, task, h,
                value_col="cond_delta_mean",
                ylabel=r"$\mathbb{E}[\sigma_{t+h}\mid funding\ extreme]-\mathbb{E}[\sigma_{t+h}]$",
                title="H4a conditioning",
                fname=out
            )
            if p is not None:
                saved.append(p)

print("Saved paper_assets to:", assets_dir.resolve())
if saved:
    print("Saved plots:")
    for p in sorted(set(saved)):
        print("  -", p.name)
else:
    print("No plots were saved. (Did you run the evaluation/aggregation cells above?)")
# Out:
# Saved paper assets to: /Users/Shana/Desktop/neural-granger-crypto/paper_assets
# Saved plots:
#   - h1_cond_RET_h1.png
#   - h1_cond_RET_h12.png
#   - h1_cond_RET_h24.png
#   - h1_cond_RET_h4.png
#   - h4a_cond_VOL_h1.png
#   - h4a_cond_VOL_h12.png
#   - h4a_cond_VOL_h24.png
#   - h4a_cond_VOL_h4.png
#   - mae_RET_h1.png
#   - mae_RET_h12.png
#   - mae_RET_h24.png
#   - mae_RET_h4.png
#   - mae_VOL_h1.png
#   - mae_VOL_h12.png
#   - mae_VOL_h24.png
#   - mae_VOL_h4.png
#   - mse_RET_h1.png
#   - mse_RET_h12.png
#   - mse_RET_h24.png
#   - mse_RET_h4.png
#   - mse_VOL_h1.png
#   - mse_VOL_h12.png
#   - mse_VOL_h24.png
#   - mse_VOL_h4.png

# %%
import os
import pandas as pd

ASSETDIR = "paper_assets"  # must match your LaTeX \assetdir
os.makedirs(ASSETDIR, exist_ok=True)

# ---- Select the exact hypotheses used in your main text table ----
want = [
    "H2 BTCret→ETHUSDTret (+)",
    "H2 BTCret→SOLUSDTret (+)",
    "H4b BTCvol→ETHUSDTvol (+)",
    "H4b BTCvol→SOLUSDTvol (+)",
]

label_map = {
    "H2 BTCret→ETHUSDTret (+)": r"BTC ret $\to$ ETH ret",
    "H2 BTCret→SOLUSDTret (+)": r"BTC ret $\to$ SOL ret",
    "H4b BTCvol→ETHUSDTvol (+)": r"BTC vol $\to$ ETH vol",
    "H4b BTCvol→SOLUSDTvol (+)": r"BTC vol $\to$ SOL vol",
}

# If not already in memory, load the exported summary CSV
if "edge_hypothesis_summary" not in globals():
    csv_path = os.path.join(ASSETDIR, "edge_hypothesis_summary.csv")
    if not os.path.exists(csv_path):
        raise FileNotFoundError(
            f"edge_hypothesis_summary not defined and CSV not found at {csv_path}. "
            "Run the edge aggregation cell first or export the CSV."
        )
    edge_hypothesis_summary = pd.read_csv(csv_path)

key = edge_hypothesis_summary[edge_hypothesis_summary["hyp"].isin(want)].copy()
key["Edge"] = key["hyp"].map(label_map)

# Cell formatting: sign fraction (median)
key["cell"] = key.apply(lambda r: f'{r["sign_frac_mean"]:.3f} ({r["median_mean"]:+.3f})', axis=1)

tab = (
    key.pivot(index="Edge", columns="h", values="cell")
       .reindex(columns=[1, 4, 12, 24])
)

tab.columns = [r"$h=1$", r"$h=4$", r"$h=12$", r"$h=24$"]

latex_tabular = tab.to_latex(
    index=True,
    escape=False,
    column_format="lcccc",
    bold_rows=False,
)

out_path = os.path.join(ASSETDIR, "edge_key_edges_table.tex")
with open(out_path, "w") as f:
    f.write(latex_tabular)

print("Wrote:", out_path)
# Out:
# Wrote: paper_assets/edge_key_edges_table.tex

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# --- config ---
assetdir = Path("paper_assets")   # match your \assetdir
assetdir.mkdir(parents=True, exist_ok=True)

# ---------------------------------------------------------------------
# Load edge_hypothesis_summary
# Option A: already computed in notebook:
#   edge_hypothesis_summary = ...
#
# Option B: load from CSV you export (recommended for robustness):
# edge_hypothesis_summary = pd.read_csv(assetdir / "edge_hypothesis_summary.csv")

df = edge_hypothesis_summary.copy()

# Expected columns (from your aggregation):
# task, h, hyp, sign_frac_mean, sign_ci_lo_mean, sign_ci_hi_mean, median_mean, med_ci_lo_mean, med_ci_hi_mean, n

# ---------------------------------------------------------------------
# Keep only the "key edges" you discuss in the main text
key_hyps = [
    "H2 BTCret→ETHUSDTret (+)",
    "H2 BTCret→SOLUSDTret (+)",
    "H4b BTCvol→ETHUSDTvol (+)",
    "H4b BTCvol→SOLUSDTvol (+)",
]

key = df[df["hyp"].isin(key_hyps)].copy()

# Map to nicer labels for the paper
label_map = {
    "H2 BTCret→ETHUSDTret (+)": r"BTC ret $\rightarrow$ ETH ret",
    "H2 BTCret→SOLUSDTret (+)": r"BTC ret $\rightarrow$ SOL ret",
    "H4b BTCvol→ETHUSDTvol (+)": r"BTC vol $\rightarrow$ ETH vol",
    "H4b BTCvol→SOLUSDTvol (+)": r"BTC vol $\rightarrow$ SOL vol",
}
key["Edge"] = key["hyp"].map(label_map)

# Ensure horizons sorted numerically
key["h"] = key["h"].astype(int)
key = key.sort_values(["Edge", "h"])

# ---------------------------------------------------------------------
# Build a wide table: each cell "signfrac (median)" or with CI if available
has_ci = {"sign_ci_lo_mean", "sign_ci_hi_mean"}.issubset(set(key.columns))

def fmt_cell(row):
    sf = row["sign_frac_mean"]
    med = row["median_mean"]
    if has_ci:
        lo = row["sign_ci_lo_mean"]
        hi = row["sign_ci_hi_mean"]
        return f"{sf:.3f} [{lo:.3f},{hi:.3f}] ({med:+.3f})"
    return f"{sf:.3f} ({med:+.3f})"

key["cell"] = key.apply(fmt_cell, axis=1)

wide = key.pivot(index="Edge", columns="h", values="cell")
wide = wide[[1,4,12,24]]  # enforce horizon order if present

# ---------------------------------------------------------------------
# Export a LaTeX table that you can \input{} to replace Table~\ref{tab:key_edges}
# Keep it simple & robust in 2-column format.
latex_lines = []
latex_lines.append(r"\begin{table}[t]")
latex_lines.append(r"\centering")
latex_lines.append(r"\small")
latex_lines.append(r"\setlength{\tabcolsep}{3.5pt}")
latex_lines.append(r"\caption{Key spillover edges by horizon. Each cell reports sign fraction (block-bootstrap 95\% CI if available) and median in parentheses, computed from the lag-aggregated adjacency $\bar A^{(h)}(t)=\sum_{k\in\{1,3,6,12\}}A_k^{(h)}(t)$ and aggregated over $n=45$ runs per horizon.}")
latex_lines.append(r"\label{tab:key_edges}")
latex_lines.append(r"\begin{tabular}{lcccc}")
latex_lines.append(r"\toprule")
latex_lines.append(r"\textbf{Edge} & $h=1$ & $h=4$ & $h=12$ & $h=24$ \\")
latex_lines.append(r"\midrule")

for edge in wide.index:
    row = wide.loc[edge]
    latex_lines.append(
        f"{edge} & {row[1]} & {row[4]} & {row[12]} & {row[24]} \\\\"
    )

latex_lines.append(r"\bottomrule")
latex_lines.append(r"\end{tabular}")
latex_lines.append(r"\end{table}")

out_table = assetdir / "key_edges_sign_table.tex"
out_table.write_text("\n".join(latex_lines))
print("Wrote:", out_table)

# ---------------------------------------------------------------------
# FIGURE: Sign fraction vs horizon for the key edges (more visually appealing)
# We'll plot mean sign fraction with CI bands if present.
fig, ax = plt.subplots(figsize=(7.5, 3.2))  # good for figure* spanning both cols

horizons = np.array([1, 4, 12, 24])

for hyp in key_hyps:
    sub = key[key["hyp"] == hyp].sort_values("h")
    y = sub["sign_frac_mean"].to_numpy()
    ax.plot(horizons, y, marker="o", linewidth=2, label=label_map[hyp])

    if has_ci:
        lo = sub["sign_ci_lo_mean"].to_numpy()
        hi = sub["sign_ci_hi_mean"].to_numpy()
        ax.fill_between(horizons, lo, hi, alpha=0.15)

ax.axhline(0.5, linestyle="--", linewidth=1)
ax.set_xticks(horizons)
ax.set_xlabel("Forecast horizon $h$ (hours)")
ax.set_ylabel("Sign fraction  (share of $t$ with edge $>0$)")
ax.set_ylim(0.0, 1.0)
ax.legend(loc="best", fontsize=8, frameon=True)
ax.set_title("Key spillover edges: sign stability across horizons (mean over $n=45$ runs/horizon)")

fig.tight_layout()
out_fig = assetdir / "edge_signfrac_keyedges.png"
fig.savefig(out_fig, dpi=200)
plt.close(fig)
print("Wrote:", out_fig)
# Out:
# Wrote: paper_assets/key_edges_sign_table.tex
# Wrote: paper_assets/edge_signfrac_keyedges.png
